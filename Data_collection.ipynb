# %%
## Dependencies

import pandas as pd
import pathlib as path



import requests
import json
from pprint import pprint

# import numpy as np
# from scipy.stats import linregress

# import matplotlib.pyplot as plt
# import hvplot.pandas
# import geopandas as gpd

# %% [markdown]
# # (1) collect immigration data

# %% [markdown]
# ##### Data source from IRCC web site
# https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv
# from
# https://ouvert.canada.ca/data/fr/dataset/f7e5498e-0ad8-4417-85c9-9b8aff9b9eda/resource/5f5fa9ca-b621-4dac-91d1-25654a25735c

# %%
### import and read csv file

path_imm = 'https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv'
imm_df = pd.read_csv(path_imm, delimiter='\t')

imm_df.to_csv('Output/immigration_raw_data.csv')
imm_df.head(5)
# Out:
#    EN_YEAR EN_QUARTER EN_MONTH  FR_ANNEÉ FR_TRIMESTRE FR_MOIS  \
# 0     2015         Q1      Feb      2015           T1    fév.
# 1     2015         Q1      Feb      2015           T1    fév.
# 2     2015         Q1      Feb      2015           T1    fév.
# 3     2015         Q1      Feb      2015           T1    fév.
# 4     2015         Q1      Feb      2015           T1    fév.
#
#   EN_COUNTRY_OF_CITIZENSHIP FR_PAYS_DE_CITOYENNETÉ TOTAL
# 0               Afghanistan            Afghanistan   125
# 1                   Albania                Albanie    25
# 2                   Algeria                Algérie   125
# 3       Antigua and Barbuda     Antigua-et-Barbuda     5
# 4                 Argentina              Argentine    15

# %%
#check datatype 

imm_df.dtypes
# Out:
# EN_YEAR                       int64
# EN_QUARTER                   object
# EN_MONTH                     object
# FR_ANNEÉ                      int64
# FR_TRIMESTRE                 object
# FR_MOIS                      object
# EN_COUNTRY_OF_CITIZENSHIP    object
# FR_PAYS_DE_CITOYENNETÉ       object
# TOTAL                        object
# dtype: object

# %%
# drop useless columns

imm_clean_df = imm_df.drop(columns=['FR_ANNEÉ','FR_TRIMESTRE','FR_MOIS','FR_PAYS_DE_CITOYENNETÉ'])
imm_clean_df.columns
# Out:
# Index(['EN_YEAR', 'EN_QUARTER', 'EN_MONTH', 'EN_COUNTRY_OF_CITIZENSHIP',
#        'TOTAL'],
#       dtype='object')

# %%
# check empty values with 1 example raw 42

print(imm_clean_df.loc[42,])
# Out:
# EN_YEAR                          2015
# EN_QUARTER                         Q1
# EN_MONTH                          Feb
# EN_COUNTRY_OF_CITIZENSHIP    Dominica
# TOTAL                              --
# Name: 42, dtype: object

# %%
# convert Total to numeric

imm_clean_df['TOTAL'] = pd.to_numeric(imm_clean_df['TOTAL'], errors='coerce')

# replace empty with 0 

imm_clean_df = imm_clean_df.fillna({'TOTAL': 0})
print(imm_clean_df.loc[42,])
# Out:
# EN_YEAR                          2015
# EN_QUARTER                         Q1
# EN_MONTH                          Feb
# EN_COUNTRY_OF_CITIZENSHIP    Dominica
# TOTAL                             0.0
# Name: 42, dtype: object

# %%
# check that total is numeric _ integer

imm_clean_df.dtypes
# Out:
# EN_YEAR                        int64
# EN_QUARTER                    object
# EN_MONTH                      object
# EN_COUNTRY_OF_CITIZENSHIP     object
# TOTAL                        float64
# dtype: object

# %%
# To DELETE ???

# imm_clean_df = imm_clean_df.drop(columns=['FR_ANNEÉ','FR_TRIMESTRE','FR_MOIS','FR_PAYS_DE_CITOYENNETÉ'])
# imm_clean_df.columns

# %%
# rename columns 

imm_clean_df = imm_clean_df.rename(columns={
                                            'EN_YEAR'            :           'year' ,
                                            'EN_QUARTER'         :          'quarter' , 
                                            'EN_MONTH'           :          'month_str' ,
                                            'EN_COUNTRY_OF_CITIZENSHIP' :   'Country' ,
                                            'TOTAL'              :           'total'
                                            })
imm_clean_df.dtypes
# Out:
# year           int64
# quarter       object
# month_str     object
# Country       object
# total        float64
# dtype: object

# %%
# add months with numerical values
 ## check that there is no strange value 

months_str = imm_clean_df['month_str'].unique()
months_str
# Out:
# array(['Feb', 'Jan', 'Mar', 'Apr', 'Jun', 'May', 'Aug', 'Jul', 'Sep',
#        'Dec', 'Nov', 'Oct'], dtype=object)

# %%
# use of Mapping to add integers to month abbreviations

month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}

# Map month abbreviations to integers using the dictionary
imm_clean_df['month_int'] = imm_clean_df['month_str'].map(month_mapping)

print(imm_clean_df.head())
# Out:
#    year quarter month_str              Country  total  month_int
# 0  2015      Q1       Feb          Afghanistan  125.0          2
# 1  2015      Q1       Feb              Albania   25.0          2
# 2  2015      Q1       Feb              Algeria  125.0          2
# 3  2015      Q1       Feb  Antigua and Barbuda    5.0          2
# 4  2015      Q1       Feb            Argentina   15.0          2

# %%
# extract useless values from country name (after the comma)
## example Congo

print(imm_clean_df.loc[34,])
# Out:
# year                                    2015
# quarter                                   Q1
# month_str                                Feb
# Country      Congo, People's Republic of the
# total                                    0.0
# month_int                                  2
# Name: 34, dtype: object

# %%
# split the country name column using delimiter ','

imm_clean_df[['country', 'country_add']] = imm_clean_df['Country']\
                                                    .str.split(',', expand=True)

print(imm_clean_df.loc[34,])
# Out:
# year                                      2015
# quarter                                     Q1
# month_str                                  Feb
# Country        Congo, People's Republic of the
# total                                      0.0
# month_int                                    2
# country                                  Congo
# country_add           People's Republic of the
# Name: 34, dtype: object

# %%
# keep only country name cleaned 

imm_clean_df = imm_clean_df.drop(columns=['Country','country_add'])
imm_clean_df.columns
# Out:
# Index(['year', 'quarter', 'month_str', 'total', 'month_int', 'country'], dtype='object')

# %%
# check with congo

print(imm_clean_df.loc[34,])
# Out:
# year          2015
# quarter         Q1
# month_str      Feb
# total          0.0
# month_int        2
# country      Congo
# Name: 34, dtype: object

# %%
# groupby country / year to get the total by country

imm_yearly = imm_clean_df.groupby(['country','year'])['total'].sum()
imm_yearly.to_csv('Output/immigrants_by_country_year.csv')
imm_yearly
# Out:
# country      year
# Afghanistan  2015    2625.0
#              2016    2655.0
#              2017    3460.0
#              2018    3560.0
#              2019    3890.0
#                       ...
# Zimbabwe     2020     335.0
#              2021     505.0
#              2022     615.0
#              2023     555.0
#              2024     505.0
# Name: total, Length: 1887, dtype: float64

# %%
# groupby to get the total by country

imm_bycountry = imm_clean_df.groupby(['country'])['total'].sum()
imm_bycountry.to_csv('Output/immigrants_by_country.csv')
imm_bycountry
# Out:
# country
# Afghanistan       81305.0
# Albania            5540.0
# Algeria           39655.0
# Andorra               0.0
# Angola              925.0
#                    ...
# Virgin Islands        0.0
# Western Sahara        0.0
# Yemen              5875.0
# Zambia              605.0
# Zimbabwe           4610.0
# Name: total, Length: 213, dtype: float64

# %% [markdown]
# # (2) create DF for countries
#
# #### information will be used to merge or generate vizualisations
# source : https://api.worldbank.org/v2/country?format=json

# %%
country_list = imm_clean_df['country'].tolist()
country_list
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Macau SAR',
#  'Macedonia',
#  'Madagascar',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Pakistan',
#  'Palestinian Authority (Gaza/West Bank)',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Samoa',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'Spain',
#  'Sri Lanka',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Stateless',
#  'Sudan',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom and Overseas Territories',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zimbabwe',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon Republic',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR',
#  'Hungary',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Morocco',
#  'Mozambique',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Pakistan',
#  'Palestinian Authority (Gaza/West Bank)',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Stateless',
#  'Sudan',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom and Overseas Territories',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon Republic',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Oman',
#  'Other',
#  'Pakistan',
#  'Palestinian Authority (Gaza/West Bank)',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts-Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Stateless',
#  'Sudan',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom and Overseas Territories',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon Republic',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR',
#  'Hungary',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Korea',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Macau SAR',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Oman',
#  'Other',
#  'Pakistan',
#  'Palestinian Authority (Gaza/West Bank)',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts-Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Stateless',
#  'Sudan',
#  'Surinam',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom and Overseas Territories',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon Republic',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macau SAR',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Oman',
#  'Other',
#  'Pakistan',
#  'Palestinian Authority (Gaza/West Bank)',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts-Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Stateless',
#  'Sudan',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom and Overseas Territories',
#  'United States of America',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon Republic',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Macau SAR',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Other',
#  'Pakistan',
#  'Palestinian Authority (Gaza/West Bank)',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Stateless',
#  'Sudan',
#  'Surinam',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom and Overseas Territories',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahama Islands',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  ...]

# %%
## retrieve all the countries from world bank API

### generate DF Countries

page = 1   ## there are 6 pages in the json file
data = []
url_countries = 'https://api.worldbank.org/v2/country?format=json'

for page in range(1,7):
    response = requests.get(f"{url_countries}&page={page}")
    json_data = response.json()
    
    # Add the data from the current page
    data.extend(json_data[1])  
    
## create DF and select columns

countries_wb_df = pd.DataFrame(data)
countries_wb_df['region'] = countries_wb_df['region'].apply(lambda x: x['value'])
countries_wb_df = countries_wb_df[['id', 'iso2Code', 'name', 'region','capitalCity', 'longitude', 'latitude']]
countries_wb_df = countries_wb_df.rename(columns={
                                                    'name':'country',
                                                    'id':'iso3Code'
                                                    })


regions = (countries_wb_df['region'] != "Aggregates")
countries_wb_df = countries_wb_df[regions]


countries_wb_df.head()
# Out:
#   iso3Code iso2Code      country                      region  \
# 0      ABW       AW        Aruba  Latin America & Caribbean
# 2      AFG       AF  Afghanistan                  South Asia
# 5      AGO       AO       Angola         Sub-Saharan Africa
# 6      ALB       AL      Albania       Europe & Central Asia
# 7      AND       AD      Andorra       Europe & Central Asia
#
#         capitalCity longitude  latitude
# 0        Oranjestad  -70.0167   12.5167
# 2             Kabul   69.1761   34.5228
# 5            Luanda    13.242  -8.81155
# 6            Tirane   19.8172   41.3317
# 7  Andorra la Vella    1.5218   42.5075

# %%
### Export to csv file in output

countries_wb_df.to_csv('Output/countries_list_UN_referential.csv')

# %% [markdown]
# # (3) Extract macro economic data
# #### from world bank API
# source : https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json

# %%
# the API uses the iso3Code code of the country (example PAK for pakistan, AFG for Afghanistan)
# we need to identify the needed countries from from our immigration_df and retrieve these iso3Code from countries_df

countries_request = pd.merge(imm_clean_df, countries_wb_df, left_on='country', right_on='country')
countries_request
# Out:
#        year quarter month_str  total  month_int               country  \
# 0      2015      Q1       Feb  125.0          2           Afghanistan
# 1      2015      Q1       Feb   25.0          2               Albania
# 2      2015      Q1       Feb  125.0          2               Algeria
# 3      2015      Q1       Feb    5.0          2   Antigua and Barbuda
# 4      2015      Q1       Feb   15.0          2             Argentina
# ...     ...     ...       ...    ...        ...                   ...
# 15932  2024      Q4       Oct    0.0         10  United Arab Emirates
# 15933  2024      Q4       Oct    5.0         10               Uruguay
# 15934  2024      Q4       Oct   15.0         10            Uzbekistan
# 15935  2024      Q4       Oct    0.0         10                Zambia
# 15936  2024      Q4       Oct   35.0         10              Zimbabwe
#
#       iso3Code iso2Code                      region   capitalCity longitude  \
# 0          AFG       AF                  South Asia         Kabul   69.1761
# 1          ALB       AL       Europe & Central Asia        Tirane   19.8172
# 2          DZA       DZ  Middle East & North Africa       Algiers   3.05097
# 3          ATG       AG  Latin America & Caribbean   Saint John's  -61.8456
# 4          ARG       AR  Latin America & Caribbean   Buenos Aires  -58.4173
# ...        ...      ...                         ...           ...       ...
# 15932      ARE       AE  Middle East & North Africa     Abu Dhabi   54.3705
# 15933      URY       UY  Latin America & Caribbean     Montevideo  -56.0675
# 15934      UZB       UZ       Europe & Central Asia      Tashkent    69.269
# 15935      ZMB       ZM         Sub-Saharan Africa         Lusaka   28.2937
# 15936      ZWE       ZW         Sub-Saharan Africa         Harare   31.0672
#
#        latitude
# 0       34.5228
# 1       41.3317
# 2       36.7397
# 3       17.1175
# 4      -34.6118
# ...         ...
# 15932   24.4764
# 15933  -34.8941
# 15934   41.3052
# 15935  -15.3982
# 15936  -17.8312
#
# [15937 rows x 12 columns]

# %%
# extrac the needed iso3code in a list to be used to iterate

country_list = countries_request['iso3Code'].unique().tolist()
country_list
# Out:
# ['AFG',
#  'ALB',
#  'DZA',
#  'ATG',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BHR',
#  'BGD',
#  'BRB',
#  'BLR',
#  'BEL',
#  'BLZ',
#  'BEN',
#  'BTN',
#  'BOL',
#  'BWA',
#  'BRA',
#  'BGR',
#  'BDI',
#  'KHM',
#  'CMR',
#  'CAF',
#  'TCD',
#  'CHL',
#  'CHN',
#  'COL',
#  'COM',
#  'CRI',
#  'HRV',
#  'CUB',
#  'CYP',
#  'DNK',
#  'DJI',
#  'DMA',
#  'DOM',
#  'ECU',
#  'SLV',
#  'ERI',
#  'ETH',
#  'FJI',
#  'FIN',
#  'FRA',
#  'GEO',
#  'DEU',
#  'GHA',
#  'GRC',
#  'GRD',
#  'GTM',
#  'GIN',
#  'GUY',
#  'HTI',
#  'HND',
#  'HUN',
#  'ISL',
#  'IND',
#  'IDN',
#  'IRQ',
#  'IRL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JPN',
#  'JOR',
#  'KAZ',
#  'KEN',
#  'XKX',
#  'LVA',
#  'LBN',
#  'LBR',
#  'LBY',
#  'LTU',
#  'MDG',
#  'MYS',
#  'MDV',
#  'MLI',
#  'MRT',
#  'MUS',
#  'MEX',
#  'MDA',
#  'MNG',
#  'MNE',
#  'MAR',
#  'NAM',
#  'NPL',
#  'NLD',
#  'NZL',
#  'NIC',
#  'NER',
#  'NGA',
#  'NOR',
#  'PAK',
#  'PAN',
#  'PRY',
#  'PER',
#  'PHL',
#  'POL',
#  'PRT',
#  'ROU',
#  'RWA',
#  'WSM',
#  'SAU',
#  'SEN',
#  'SRB',
#  'SLE',
#  'SGP',
#  'SVK',
#  'SVN',
#  'SOM',
#  'ZAF',
#  'ESP',
#  'LKA',
#  'LCA',
#  'VCT',
#  'SDN',
#  'SWE',
#  'CHE',
#  'TJK',
#  'TZA',
#  'THA',
#  'TGO',
#  'TTO',
#  'TUN',
#  'UGA',
#  'UKR',
#  'URY',
#  'UZB',
#  'ZWE',
#  'AGO',
#  'EST',
#  'KWT',
#  'LUX',
#  'MWI',
#  'MOZ',
#  'SLB',
#  'SSD',
#  'TON',
#  'ZMB',
#  'OMN',
#  'AND',
#  'GNB',
#  'MLT',
#  'TKM',
#  'PNG',
#  'ARE',
#  'QAT',
#  'LSO',
#  'MCO',
#  'SYC',
#  'GNQ',
#  'KIR',
#  'SMR',
#  'PLW',
#  'MHL',
#  'BMU',
#  'NCL',
#  'MNP',
#  'CUW',
#  'TUV',
#  'LIE',
#  'PRI',
#  'PYF',
#  'NRU',
#  'STP',
#  'VUT']

# %%
import requests

# %%
# this line is just to check that we are connected to the APIT : O TEST before loop

link_pop = f'https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json'
response_pop = requests.get(link_pop).json()

pprint(response_pop)
# Out:
# [{'lastupdated': '2024-12-16',
#   'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'sourceid': '2',
#   'total': 9},
#  [{'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2023',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4660.40545686886},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2022',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4544.46688059647},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2021',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4456.74687641147},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2020',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4363.68533766912},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2019',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4672.66408682198},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2018',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4717.00358853556},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2017',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4742.90075536604},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2016',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4768.73140080218},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2015',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4685.05902729002}]]

# %%
# this cell is used to check our code before to launch the loop 
# TO TEST before loop


link_pop = f'https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json'
response_pop = requests.get(link_pop).json()

# pprint(response_pop)

pop_list = []
for item in response_pop[1]:  # Assuming response_pop[1] is a list of dictionaries
    pop_list.append({
        'iso3Code': item['countryiso3code'],
        'iso2Code': item['country']['id'],
        'Country': item['country']['value'],              
        'year': item['date'],
        'indicator': item['indicator']['value'],
        'value': item['value']
    })

pop_list
# Out:
# [{'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2023',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4660.40545686886},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2022',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4544.46688059647},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2021',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4456.74687641147},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2020',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4363.68533766912},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2019',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4672.66408682198},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2018',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4717.00358853556},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2017',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4742.90075536604},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2016',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4768.73140080218},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2015',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4685.05902729002}]

# %%
# DEFINE THE VARIABLES : INDICATORS, TIME PERIOD

# create the list of indicators
            #  'NY.GDP.PCAP.KD' gdp per capita
            # 'SP.POP.TOTL' total population
            #  SL.UEM.ADVN.ZS : Unemployment with advanced education (% of total labor force with advanced education)
            # SL.UEM.TOTL.NE.ZS : Unemployment, total (% of total labor force) (national estimate)
            # SI.POV.DDAY  Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)

            # Population density (people per sq. km of land area)	EN.POP.DNST
            # Level of water stress: freshwater withdrawal as a proportion of available freshwater resources	ER.H2O.FWST.ZS
            # Market capitalization of listed domestic companies (% of GDP) CM.MKT.LCAP.GD.ZS
            # Rural population (% of total population) SP.RUR.TOTL.ZS
            # S&P Global Equity Indices (annual % change)	CM.MKT.INDX.ZG
            # Voice and Accountability: Number of Sources	VA.NO.SRC



indicators = ['NY.GDP.PCAP.KD','SP.POP.TOTL' , 'SL.UEM.ADVN.ZS', 'SL.UEM.TOTL.NE.ZS', 'SI.POV.DDAY',
              'EN.POP.DNST', 'ER.H2O.FWST.ZS', 'CM.MKT.LCAP.GD.ZS', 'SP.RUR.TOTL.ZS', 'CM.MKT.INDX.ZG', 'VA.NO.SRC' ]

# define 1st and last year f the loop

year_min = 2015
year_max = 2024
years_list = [x for x in range(year_min, year_max +1)]   # COULD BE USED BUT NOT IN THE CURRENT CODE

# %%
# lOOP to extrac tdata from API : between 7 and 9 minutes

# this code will loop through all the listed countries and the needed indicators to generate a list

print(f"start code")
print('---------------------------')

macro_eco_data_list = []

# the end point is defined by (i) country (II) indicator (III) year start and year end
        # => we need to create 1 end point of each country / indicator

for i in country_list :

    for j in indicators :

        print(f"--------------------------")
        print(f"country {i} indicator {j}")

        try:

            # define the end point by country (from list I) and indicator (from list J)

            link_pop = f'https://api.worldbank.org/v2/country/{i}/indicator/{j}?date={year_min}:{year_max}&format=json'
            response_pop = requests.get(link_pop).json()

            # loop through the response_pop (list) to extract the value for each year in the serie 

            for item in response_pop[1]:  
                macro_eco_data_list.append({
                    'iso3Code': item['countryiso3code'],
                    'iso2Code': item['country']['id'],
                    'country': item['country']['value'],              
                    'year': item['date'],
                    'indicator': item['indicator']['value'],
                    'value': item['value']
                })
        except:   
            print(f"country {i} indicator {j}....... not found")
# Out:
# start code
# ---------------------------
# --------------------------
# country AFG indicator NY.GDP.PCAP.KD
# --------------------------
# country AFG indicator SP.POP.TOTL
# --------------------------
# country AFG indicator SL.UEM.ADVN.ZS
# --------------------------
# country AFG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AFG indicator SI.POV.DDAY
# --------------------------
# country AFG indicator EN.POP.DNST
# --------------------------
# country AFG indicator ER.H2O.FWST.ZS
# --------------------------
# country AFG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AFG indicator SP.RUR.TOTL.ZS
# --------------------------
# country AFG indicator CM.MKT.INDX.ZG
# --------------------------
# country AFG indicator VA.NO.SRC
# --------------------------
# country ALB indicator NY.GDP.PCAP.KD
# --------------------------
# country ALB indicator SP.POP.TOTL
# --------------------------
# country ALB indicator SL.UEM.ADVN.ZS
# --------------------------
# country ALB indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ALB indicator SI.POV.DDAY
# --------------------------
# country ALB indicator EN.POP.DNST
# --------------------------
# country ALB indicator ER.H2O.FWST.ZS
# --------------------------
# country ALB indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ALB indicator SP.RUR.TOTL.ZS
# --------------------------
# country ALB indicator CM.MKT.INDX.ZG
# --------------------------
# country ALB indicator VA.NO.SRC
# --------------------------
# country DZA indicator NY.GDP.PCAP.KD
# --------------------------
# country DZA indicator SP.POP.TOTL
# --------------------------
# country DZA indicator SL.UEM.ADVN.ZS
# --------------------------
# country DZA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DZA indicator SI.POV.DDAY
# --------------------------
# country DZA indicator EN.POP.DNST
# --------------------------
# country DZA indicator ER.H2O.FWST.ZS
# --------------------------
# country DZA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DZA indicator SP.RUR.TOTL.ZS
# --------------------------
# country DZA indicator CM.MKT.INDX.ZG
# --------------------------
# country DZA indicator VA.NO.SRC
# --------------------------
# country ATG indicator NY.GDP.PCAP.KD
# --------------------------
# country ATG indicator SP.POP.TOTL
# --------------------------
# country ATG indicator SL.UEM.ADVN.ZS
# --------------------------
# country ATG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ATG indicator SI.POV.DDAY
# --------------------------
# country ATG indicator EN.POP.DNST
# --------------------------
# country ATG indicator ER.H2O.FWST.ZS
# --------------------------
# country ATG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ATG indicator SP.RUR.TOTL.ZS
# --------------------------
# country ATG indicator CM.MKT.INDX.ZG
# --------------------------
# country ATG indicator VA.NO.SRC
# --------------------------
# country ARG indicator NY.GDP.PCAP.KD
# --------------------------
# country ARG indicator SP.POP.TOTL
# --------------------------
# country ARG indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ARG indicator SI.POV.DDAY
# --------------------------
# country ARG indicator EN.POP.DNST
# --------------------------
# country ARG indicator ER.H2O.FWST.ZS
# --------------------------
# country ARG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ARG indicator SP.RUR.TOTL.ZS
# --------------------------
# country ARG indicator CM.MKT.INDX.ZG
# --------------------------
# country ARG indicator VA.NO.SRC
# --------------------------
# country ARM indicator NY.GDP.PCAP.KD
# --------------------------
# country ARM indicator SP.POP.TOTL
# --------------------------
# country ARM indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ARM indicator SI.POV.DDAY
# --------------------------
# country ARM indicator EN.POP.DNST
# --------------------------
# country ARM indicator ER.H2O.FWST.ZS
# --------------------------
# country ARM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ARM indicator SP.RUR.TOTL.ZS
# --------------------------
# country ARM indicator CM.MKT.INDX.ZG
# --------------------------
# country ARM indicator VA.NO.SRC
# --------------------------
# country AUS indicator NY.GDP.PCAP.KD
# --------------------------
# country AUS indicator SP.POP.TOTL
# --------------------------
# country AUS indicator SL.UEM.ADVN.ZS
# --------------------------
# country AUS indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AUS indicator SI.POV.DDAY
# --------------------------
# country AUS indicator EN.POP.DNST
# --------------------------
# country AUS indicator ER.H2O.FWST.ZS
# --------------------------
# country AUS indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AUS indicator SP.RUR.TOTL.ZS
# --------------------------
# country AUS indicator CM.MKT.INDX.ZG
# --------------------------
# country AUS indicator VA.NO.SRC
# --------------------------
# country AUT indicator NY.GDP.PCAP.KD
# --------------------------
# country AUT indicator SP.POP.TOTL
# --------------------------
# country AUT indicator SL.UEM.ADVN.ZS
# --------------------------
# country AUT indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AUT indicator SI.POV.DDAY
# --------------------------
# country AUT indicator EN.POP.DNST
# --------------------------
# country AUT indicator ER.H2O.FWST.ZS
# --------------------------
# country AUT indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AUT indicator SP.RUR.TOTL.ZS
# --------------------------
# country AUT indicator CM.MKT.INDX.ZG
# --------------------------
# country AUT indicator VA.NO.SRC
# --------------------------
# country AZE indicator NY.GDP.PCAP.KD
# --------------------------
# country AZE indicator SP.POP.TOTL
# --------------------------
# country AZE indicator SL.UEM.ADVN.ZS
# --------------------------
# country AZE indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AZE indicator SI.POV.DDAY
# --------------------------
# country AZE indicator EN.POP.DNST
# --------------------------
# country AZE indicator ER.H2O.FWST.ZS
# --------------------------
# country AZE indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AZE indicator SP.RUR.TOTL.ZS
# --------------------------
# country AZE indicator CM.MKT.INDX.ZG
# --------------------------
# country AZE indicator VA.NO.SRC
# --------------------------
# country BHR indicator NY.GDP.PCAP.KD
# --------------------------
# country BHR indicator SP.POP.TOTL
# --------------------------
# country BHR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BHR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BHR indicator SI.POV.DDAY
# --------------------------
# country BHR indicator EN.POP.DNST
# --------------------------
# country BHR indicator ER.H2O.FWST.ZS
# --------------------------
# country BHR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BHR indicator SP.RUR.TOTL.ZS
# --------------------------
# country BHR indicator CM.MKT.INDX.ZG
# --------------------------
# country BHR indicator VA.NO.SRC
# --------------------------
# country BGD indicator NY.GDP.PCAP.KD
# --------------------------
# country BGD indicator SP.POP.TOTL
# --------------------------
# country BGD indicator SL.UEM.ADVN.ZS
# --------------------------
# country BGD indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BGD indicator SI.POV.DDAY
# --------------------------
# country BGD indicator EN.POP.DNST
# --------------------------
# country BGD indicator ER.H2O.FWST.ZS
# --------------------------
# country BGD indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BGD indicator SP.RUR.TOTL.ZS
# --------------------------
# country BGD indicator CM.MKT.INDX.ZG
# --------------------------
# country BGD indicator VA.NO.SRC
# --------------------------
# country BRB indicator NY.GDP.PCAP.KD
# --------------------------
# country BRB indicator SP.POP.TOTL
# --------------------------
# country BRB indicator SL.UEM.ADVN.ZS
# --------------------------
# country BRB indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BRB indicator SI.POV.DDAY
# --------------------------
# country BRB indicator EN.POP.DNST
# --------------------------
# country BRB indicator ER.H2O.FWST.ZS
# --------------------------
# country BRB indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BRB indicator SP.RUR.TOTL.ZS
# --------------------------
# country BRB indicator CM.MKT.INDX.ZG
# --------------------------
# country BRB indicator VA.NO.SRC
# --------------------------
# country BLR indicator NY.GDP.PCAP.KD
# --------------------------
# country BLR indicator SP.POP.TOTL
# --------------------------
# country BLR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BLR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BLR indicator SI.POV.DDAY
# --------------------------
# country BLR indicator EN.POP.DNST
# --------------------------
# country BLR indicator ER.H2O.FWST.ZS
# --------------------------
# country BLR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BLR indicator SP.RUR.TOTL.ZS
# --------------------------
# country BLR indicator CM.MKT.INDX.ZG
# --------------------------
# country BLR indicator VA.NO.SRC
# --------------------------
# country BEL indicator NY.GDP.PCAP.KD
# --------------------------
# country BEL indicator SP.POP.TOTL
# --------------------------
# country BEL indicator SL.UEM.ADVN.ZS
# --------------------------
# country BEL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BEL indicator SI.POV.DDAY
# --------------------------
# country BEL indicator EN.POP.DNST
# --------------------------
# country BEL indicator ER.H2O.FWST.ZS
# --------------------------
# country BEL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BEL indicator SP.RUR.TOTL.ZS
# --------------------------
# country BEL indicator CM.MKT.INDX.ZG
# --------------------------
# country BEL indicator VA.NO.SRC
# --------------------------
# country BLZ indicator NY.GDP.PCAP.KD
# --------------------------
# country BLZ indicator SP.POP.TOTL
# --------------------------
# country BLZ indicator SL.UEM.ADVN.ZS
# --------------------------
# country BLZ indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BLZ indicator SI.POV.DDAY
# --------------------------
# country BLZ indicator EN.POP.DNST
# --------------------------
# country BLZ indicator ER.H2O.FWST.ZS
# --------------------------
# country BLZ indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BLZ indicator SP.RUR.TOTL.ZS
# --------------------------
# country BLZ indicator CM.MKT.INDX.ZG
# --------------------------
# country BLZ indicator VA.NO.SRC
# --------------------------
# country BEN indicator NY.GDP.PCAP.KD
# --------------------------
# country BEN indicator SP.POP.TOTL
# --------------------------
# country BEN indicator SL.UEM.ADVN.ZS
# --------------------------
# country BEN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BEN indicator SI.POV.DDAY
# --------------------------
# country BEN indicator EN.POP.DNST
# --------------------------
# country BEN indicator ER.H2O.FWST.ZS
# --------------------------
# country BEN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BEN indicator SP.RUR.TOTL.ZS
# --------------------------
# country BEN indicator CM.MKT.INDX.ZG
# --------------------------
# country BEN indicator VA.NO.SRC
# --------------------------
# country BTN indicator NY.GDP.PCAP.KD
# --------------------------
# country BTN indicator SP.POP.TOTL
# --------------------------
# country BTN indicator SL.UEM.ADVN.ZS
# --------------------------
# country BTN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BTN indicator SI.POV.DDAY
# --------------------------
# country BTN indicator EN.POP.DNST
# --------------------------
# country BTN indicator ER.H2O.FWST.ZS
# --------------------------
# country BTN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BTN indicator SP.RUR.TOTL.ZS
# --------------------------
# country BTN indicator CM.MKT.INDX.ZG
# --------------------------
# country BTN indicator VA.NO.SRC
# --------------------------
# country BOL indicator NY.GDP.PCAP.KD
# --------------------------
# country BOL indicator SP.POP.TOTL
# --------------------------
# country BOL indicator SL.UEM.ADVN.ZS
# --------------------------
# country BOL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BOL indicator SI.POV.DDAY
# --------------------------
# country BOL indicator EN.POP.DNST
# --------------------------
# country BOL indicator ER.H2O.FWST.ZS
# --------------------------
# country BOL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BOL indicator SP.RUR.TOTL.ZS
# --------------------------
# country BOL indicator CM.MKT.INDX.ZG
# --------------------------
# country BOL indicator VA.NO.SRC
# --------------------------
# country BWA indicator NY.GDP.PCAP.KD
# --------------------------
# country BWA indicator SP.POP.TOTL
# --------------------------
# country BWA indicator SL.UEM.ADVN.ZS
# --------------------------
# country BWA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BWA indicator SI.POV.DDAY
# --------------------------
# country BWA indicator EN.POP.DNST
# --------------------------
# country BWA indicator ER.H2O.FWST.ZS
# --------------------------
# country BWA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BWA indicator SP.RUR.TOTL.ZS
# --------------------------
# country BWA indicator CM.MKT.INDX.ZG
# --------------------------
# country BWA indicator VA.NO.SRC
# --------------------------
# country BRA indicator NY.GDP.PCAP.KD
# --------------------------
# country BRA indicator SP.POP.TOTL
# --------------------------
# country BRA indicator SL.UEM.ADVN.ZS
# --------------------------
# country BRA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BRA indicator SI.POV.DDAY
# --------------------------
# country BRA indicator EN.POP.DNST
# --------------------------
# country BRA indicator ER.H2O.FWST.ZS
# --------------------------
# country BRA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BRA indicator SP.RUR.TOTL.ZS
# --------------------------
# country BRA indicator CM.MKT.INDX.ZG
# --------------------------
# country BRA indicator VA.NO.SRC
# --------------------------
# country BGR indicator NY.GDP.PCAP.KD
# --------------------------
# country BGR indicator SP.POP.TOTL
# --------------------------
# country BGR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BGR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BGR indicator SI.POV.DDAY
# --------------------------
# country BGR indicator EN.POP.DNST
# --------------------------
# country BGR indicator ER.H2O.FWST.ZS
# --------------------------
# country BGR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BGR indicator SP.RUR.TOTL.ZS
# --------------------------
# country BGR indicator CM.MKT.INDX.ZG
# --------------------------
# country BGR indicator VA.NO.SRC
# --------------------------
# country BDI indicator NY.GDP.PCAP.KD
# --------------------------
# country BDI indicator SP.POP.TOTL
# --------------------------
# country BDI indicator SL.UEM.ADVN.ZS
# --------------------------
# country BDI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BDI indicator SI.POV.DDAY
# --------------------------
# country BDI indicator EN.POP.DNST
# --------------------------
# country BDI indicator ER.H2O.FWST.ZS
# --------------------------
# country BDI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BDI indicator SP.RUR.TOTL.ZS
# --------------------------
# country BDI indicator CM.MKT.INDX.ZG
# --------------------------
# country BDI indicator VA.NO.SRC
# --------------------------
# country KHM indicator NY.GDP.PCAP.KD
# --------------------------
# country KHM indicator SP.POP.TOTL
# --------------------------
# country KHM indicator SL.UEM.ADVN.ZS
# --------------------------
# country KHM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country KHM indicator SI.POV.DDAY
# --------------------------
# country KHM indicator EN.POP.DNST
# --------------------------
# country KHM indicator ER.H2O.FWST.ZS
# --------------------------
# country KHM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country KHM indicator SP.RUR.TOTL.ZS
# --------------------------
# country KHM indicator CM.MKT.INDX.ZG
# --------------------------
# country KHM indicator VA.NO.SRC
# --------------------------
# country CMR indicator NY.GDP.PCAP.KD
# --------------------------
# country CMR indicator SP.POP.TOTL
# --------------------------
# country CMR indicator SL.UEM.ADVN.ZS
# --------------------------
# country CMR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CMR indicator SI.POV.DDAY
# --------------------------
# country CMR indicator EN.POP.DNST
# --------------------------
# country CMR indicator ER.H2O.FWST.ZS
# --------------------------
# country CMR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CMR indicator SP.RUR.TOTL.ZS
# --------------------------
# country CMR indicator CM.MKT.INDX.ZG
# --------------------------
# country CMR indicator VA.NO.SRC
# --------------------------
# country CAF indicator NY.GDP.PCAP.KD
# --------------------------
# country CAF indicator SP.POP.TOTL
# --------------------------
# country CAF indicator SL.UEM.ADVN.ZS
# --------------------------
# country CAF indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CAF indicator SI.POV.DDAY
# --------------------------
# country CAF indicator EN.POP.DNST
# --------------------------
# country CAF indicator ER.H2O.FWST.ZS
# --------------------------
# country CAF indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CAF indicator SP.RUR.TOTL.ZS
# --------------------------
# country CAF indicator CM.MKT.INDX.ZG
# --------------------------
# country CAF indicator VA.NO.SRC
# --------------------------
# country TCD indicator NY.GDP.PCAP.KD
# --------------------------
# country TCD indicator SP.POP.TOTL
# --------------------------
# country TCD indicator SL.UEM.ADVN.ZS
# --------------------------
# country TCD indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country TCD indicator SI.POV.DDAY
# --------------------------
# country TCD indicator EN.POP.DNST
# --------------------------
# country TCD indicator ER.H2O.FWST.ZS
# --------------------------
# country TCD indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country TCD indicator SP.RUR.TOTL.ZS
# --------------------------
# country TCD indicator CM.MKT.INDX.ZG
# --------------------------
# country TCD indicator VA.NO.SRC
# --------------------------
# country CHL indicator NY.GDP.PCAP.KD
# --------------------------
# country CHL indicator SP.POP.TOTL
# --------------------------
# country CHL indicator SL.UEM.ADVN.ZS
# --------------------------
# country CHL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CHL indicator SI.POV.DDAY
# --------------------------
# country CHL indicator EN.POP.DNST
# --------------------------
# country CHL indicator ER.H2O.FWST.ZS
# --------------------------
# country CHL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CHL indicator SP.RUR.TOTL.ZS
# --------------------------
# country CHL indicator CM.MKT.INDX.ZG
# --------------------------
# country CHL indicator VA.NO.SRC
# --------------------------
# country CHN indicator NY.GDP.PCAP.KD
# --------------------------
# country CHN indicator SP.POP.TOTL
# --------------------------
# country CHN indicator SL.UEM.ADVN.ZS
# --------------------------
# country CHN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CHN indicator SI.POV.DDAY
# --------------------------
# country CHN indicator EN.POP.DNST
# --------------------------
# country CHN indicator ER.H2O.FWST.ZS
# --------------------------
# country CHN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CHN indicator SP.RUR.TOTL.ZS
# --------------------------
# country CHN indicator CM.MKT.INDX.ZG
# --------------------------
# country CHN indicator VA.NO.SRC
# --------------------------
# country COL indicator NY.GDP.PCAP.KD
# --------------------------
# country COL indicator SP.POP.TOTL
# --------------------------
# country COL indicator SL.UEM.ADVN.ZS
# --------------------------
# country COL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country COL indicator SI.POV.DDAY
# --------------------------
# country COL indicator EN.POP.DNST
# --------------------------
# country COL indicator ER.H2O.FWST.ZS
# --------------------------
# country COL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country COL indicator SP.RUR.TOTL.ZS
# --------------------------
# country COL indicator CM.MKT.INDX.ZG
# --------------------------
# country COL indicator VA.NO.SRC
# --------------------------
# country COM indicator NY.GDP.PCAP.KD
# --------------------------
# country COM indicator SP.POP.TOTL
# --------------------------
# country COM indicator SL.UEM.ADVN.ZS
# --------------------------
# country COM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country COM indicator SI.POV.DDAY
# --------------------------
# country COM indicator EN.POP.DNST
# --------------------------
# country COM indicator ER.H2O.FWST.ZS
# --------------------------
# country COM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country COM indicator SP.RUR.TOTL.ZS
# --------------------------
# country COM indicator CM.MKT.INDX.ZG
# --------------------------
# country COM indicator VA.NO.SRC
# --------------------------
# country CRI indicator NY.GDP.PCAP.KD
# --------------------------
# country CRI indicator SP.POP.TOTL
# --------------------------
# country CRI indicator SL.UEM.ADVN.ZS
# --------------------------
# country CRI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CRI indicator SI.POV.DDAY
# --------------------------
# country CRI indicator EN.POP.DNST
# --------------------------
# country CRI indicator ER.H2O.FWST.ZS
# --------------------------
# country CRI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CRI indicator SP.RUR.TOTL.ZS
# --------------------------
# country CRI indicator CM.MKT.INDX.ZG
# --------------------------
# country CRI indicator VA.NO.SRC
# --------------------------
# country HRV indicator NY.GDP.PCAP.KD
# --------------------------
# country HRV indicator SP.POP.TOTL
# --------------------------
# country HRV indicator SL.UEM.ADVN.ZS
# --------------------------
# country HRV indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country HRV indicator SI.POV.DDAY
# --------------------------
# country HRV indicator EN.POP.DNST
# --------------------------
# country HRV indicator ER.H2O.FWST.ZS
# --------------------------
# country HRV indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country HRV indicator SP.RUR.TOTL.ZS
# --------------------------
# country HRV indicator CM.MKT.INDX.ZG
# --------------------------
# country HRV indicator VA.NO.SRC
# --------------------------
# country CUB indicator NY.GDP.PCAP.KD
# --------------------------
# country CUB indicator SP.POP.TOTL
# --------------------------
# country CUB indicator SL.UEM.ADVN.ZS
# --------------------------
# country CUB indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CUB indicator SI.POV.DDAY
# --------------------------
# country CUB indicator EN.POP.DNST
# --------------------------
# country CUB indicator ER.H2O.FWST.ZS
# --------------------------
# country CUB indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CUB indicator SP.RUR.TOTL.ZS
# --------------------------
# country CUB indicator CM.MKT.INDX.ZG
# --------------------------
# country CUB indicator VA.NO.SRC
# --------------------------
# country CYP indicator NY.GDP.PCAP.KD
# --------------------------
# country CYP indicator SP.POP.TOTL
# --------------------------
# country CYP indicator SL.UEM.ADVN.ZS
# --------------------------
# country CYP indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CYP indicator SI.POV.DDAY
# --------------------------
# country CYP indicator EN.POP.DNST
# --------------------------
# country CYP indicator ER.H2O.FWST.ZS
# --------------------------
# country CYP indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CYP indicator SP.RUR.TOTL.ZS
# --------------------------
# country CYP indicator CM.MKT.INDX.ZG
# --------------------------
# country CYP indicator VA.NO.SRC
# --------------------------
# country DNK indicator NY.GDP.PCAP.KD
# --------------------------
# country DNK indicator SP.POP.TOTL
# --------------------------
# country DNK indicator SL.UEM.ADVN.ZS
# --------------------------
# country DNK indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DNK indicator SI.POV.DDAY
# --------------------------
# country DNK indicator EN.POP.DNST
# --------------------------
# country DNK indicator ER.H2O.FWST.ZS
# --------------------------
# country DNK indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DNK indicator SP.RUR.TOTL.ZS
# --------------------------
# country DNK indicator CM.MKT.INDX.ZG
# --------------------------
# country DNK indicator VA.NO.SRC
# --------------------------
# country DJI indicator NY.GDP.PCAP.KD
# --------------------------
# country DJI indicator SP.POP.TOTL
# --------------------------
# country DJI indicator SL.UEM.ADVN.ZS
# --------------------------
# country DJI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DJI indicator SI.POV.DDAY
# --------------------------
# country DJI indicator EN.POP.DNST
# --------------------------
# country DJI indicator ER.H2O.FWST.ZS
# --------------------------
# country DJI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DJI indicator SP.RUR.TOTL.ZS
# --------------------------
# country DJI indicator CM.MKT.INDX.ZG
# --------------------------
# country DJI indicator VA.NO.SRC
# --------------------------
# country DMA indicator NY.GDP.PCAP.KD
# --------------------------
# country DMA indicator SP.POP.TOTL
# --------------------------
# country DMA indicator SL.UEM.ADVN.ZS
# --------------------------
# country DMA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DMA indicator SI.POV.DDAY
# --------------------------
# country DMA indicator EN.POP.DNST
# --------------------------
# country DMA indicator ER.H2O.FWST.ZS
# --------------------------
# country DMA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DMA indicator SP.RUR.TOTL.ZS
# --------------------------
# country DMA indicator CM.MKT.INDX.ZG
# --------------------------
# country DMA indicator VA.NO.SRC
# --------------------------
# country DOM indicator NY.GDP.PCAP.KD
# --------------------------
# country DOM indicator SP.POP.TOTL
# --------------------------
# country DOM indicator SL.UEM.ADVN.ZS
# --------------------------
# country DOM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DOM indicator SI.POV.DDAY
# --------------------------
# country DOM indicator EN.POP.DNST
# --------------------------
# country DOM indicator ER.H2O.FWST.ZS
# --------------------------
# country DOM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DOM indicator SP.RUR.TOTL.ZS
# --------------------------
# country DOM indicator CM.MKT.INDX.ZG
# --------------------------
# country DOM indicator VA.NO.SRC
# --------------------------
# country ECU indicator NY.GDP.PCAP.KD
# --------------------------
# country ECU indicator SP.POP.TOTL
# --------------------------
# country ECU indicator SL.UEM.ADVN.ZS
# --------------------------
# country ECU indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ECU indicator SI.POV.DDAY
# --------------------------
# country ECU indicator EN.POP.DNST
# --------------------------
# country ECU indicator ER.H2O.FWST.ZS
# --------------------------
# country ECU indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ECU indicator SP.RUR.TOTL.ZS
# --------------------------
# country ECU indicator CM.MKT.INDX.ZG
# --------------------------
# country ECU indicator VA.NO.SRC
# --------------------------
# country SLV indicator NY.GDP.PCAP.KD
# --------------------------
# country SLV indicator SP.POP.TOTL
# --------------------------
# country SLV indicator SL.UEM.ADVN.ZS
# --------------------------
# country SLV indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country SLV indicator SI.POV.DDAY
# --------------------------
# country SLV indicator EN.POP.DNST
# --------------------------
# country SLV indicator ER.H2O.FWST.ZS
# --------------------------
# country SLV indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country SLV indicator SP.RUR.TOTL.ZS
# --------------------------
# country SLV indicator CM.MKT.INDX.ZG
# --------------------------
# country SLV indicator VA.NO.SRC
# --------------------------
# country ERI indicator NY.GDP.PCAP.KD
# --------------------------
# country ERI indicator SP.POP.TOTL
# --------------------------
# country ERI indicator SL.UEM.ADVN.ZS
# --------------------------
# country ERI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ERI indicator SI.POV.DDAY
# --------------------------
# country ERI indicator EN.POP.DNST
# --------------------------
# country ERI indicator ER.H2O.FWST.ZS
# --------------------------
# country ERI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ERI indicator SP.RUR.TOTL.ZS
# --------------------------
# country ERI indicator CM.MKT.INDX.ZG
# --------------------------
# country ERI indicator VA.NO.SRC
# --------------------------
# country ETH indicator NY.GDP.PCAP.KD
# --------------------------
# country ETH indicator SP.POP.TOTL
# --------------------------
# country ETH indicator SL.UEM.ADVN.ZS
# --------------------------
# country ETH indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ETH indicator SI.POV.DDAY
# --------------------------
# country ETH indicator EN.POP.DNST
# --------------------------
# country ETH indicator ER.H2O.FWST.ZS
# --------------------------
# country ETH indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ETH indicator SP.RUR.TOTL.ZS
# --------------------------
# country ETH indicator CM.MKT.INDX.ZG
# --------------------------
# country ETH indicator VA.NO.SRC
# --------------------------
# country FJI indicator NY.GDP.PCAP.KD
# --------------------------
# country FJI indicator SP.POP.TOTL
# --------------------------
# country FJI indicator SL.UEM.ADVN.ZS
# --------------------------
# country FJI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country FJI indicator SI.POV.DDAY
# --------------------------
# country FJI indicator EN.POP.DNST
# --------------------------
# country FJI indicator ER.H2O.FWST.ZS
# --------------------------
# country FJI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country FJI indicator SP.RUR.TOTL.ZS
# --------------------------
# country FJI indicator CM.MKT.INDX.ZG
# --------------------------
# country FJI indicator VA.NO.SRC
# --------------------------
# country FIN indicator NY.GDP.PCAP.KD
# --------------------------
# country FIN indicator SP.POP.TOTL
# --------------------------
# country FIN indicator SL.UEM.ADVN.ZS
# --------------------------
# country FIN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country FIN indicator SI.POV.DDAY
# --------------------------
# country FIN indicator EN.POP.DNST
# --------------------------
# country FIN indicator ER.H2O.FWST.ZS
# --------------------------
# country FIN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country FIN indicator SP.RUR.TOTL.ZS
# --------------------------
# country FIN indicator CM.MKT.INDX.ZG
# --------------------------
# country FIN indicator VA.NO.SRC
# --------------------------
# country FRA indicator NY.GDP.PCAP.KD
# --------------------------
# country FRA indicator SP.POP.TOTL
# --------------------------
# country FRA indicator SL.UEM.ADVN.ZS
# --------------------------
# country FRA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country FRA indicator SI.POV.DDAY
# --------------------------
# country FRA indicator EN.POP.DNST
# --------------------------
# country FRA indicator ER.H2O.FWST.ZS
# --------------------------
# country FRA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country FRA indicator SP.RUR.TOTL.ZS
# --------------------------
# country FRA indicator CM.MKT.INDX.ZG
# --------------------------
# country FRA indicator VA.NO.SRC
# --------------------------
# country GEO indicator NY.GDP.PCAP.KD
# --------------------------
# country GEO indicator SP.POP.TOTL
# --------------------------
# country GEO indicator SL.UEM.ADVN.ZS
# --------------------------
# country GEO indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GEO indicator SI.POV.DDAY
# --------------------------
# country GEO indicator EN.POP.DNST
# --------------------------
# country GEO indicator ER.H2O.FWST.ZS
# --------------------------
# country GEO indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GEO indicator SP.RUR.TOTL.ZS
# --------------------------
# country GEO indicator CM.MKT.INDX.ZG
# --------------------------
# country GEO indicator VA.NO.SRC
# --------------------------
# country DEU indicator NY.GDP.PCAP.KD
# --------------------------
# country DEU indicator SP.POP.TOTL
# --------------------------
# country DEU indicator SL.UEM.ADVN.ZS
# --------------------------
# country DEU indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DEU indicator SI.POV.DDAY
# --------------------------
# country DEU indicator EN.POP.DNST
# --------------------------
# country DEU indicator ER.H2O.FWST.ZS
# --------------------------
# country DEU indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DEU indicator SP.RUR.TOTL.ZS
# --------------------------
# country DEU indicator CM.MKT.INDX.ZG
# --------------------------
# country DEU indicator VA.NO.SRC
# --------------------------
# country GHA indicator NY.GDP.PCAP.KD
# --------------------------
# country GHA indicator SP.POP.TOTL
# --------------------------
# country GHA indicator SL.UEM.ADVN.ZS
# --------------------------
# country GHA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GHA indicator SI.POV.DDAY
# --------------------------
# country GHA indicator EN.POP.DNST
# --------------------------
# country GHA indicator ER.H2O.FWST.ZS
# --------------------------
# country GHA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GHA indicator SP.RUR.TOTL.ZS
# --------------------------
# country GHA indicator CM.MKT.INDX.ZG
# --------------------------
# country GHA indicator VA.NO.SRC
# --------------------------
# country GRC indicator NY.GDP.PCAP.KD
# --------------------------
# country GRC indicator SP.POP.TOTL
# --------------------------
# country GRC indicator SL.UEM.ADVN.ZS
# --------------------------
# country GRC indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GRC indicator SI.POV.DDAY
# --------------------------
# country GRC indicator EN.POP.DNST
# --------------------------
# country GRC indicator ER.H2O.FWST.ZS
# --------------------------
# country GRC indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GRC indicator SP.RUR.TOTL.ZS
# --------------------------
# country GRC indicator CM.MKT.INDX.ZG
# --------------------------
# country GRC indicator VA.NO.SRC
# --------------------------
# country GRD indicator NY.GDP.PCAP.KD
# --------------------------
# country GRD indicator SP.POP.TOTL
# --------------------------
# country GRD indicator SL.UEM.ADVN.ZS
# --------------------------
# country GRD indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GRD indicator SI.POV.DDAY
# --------------------------
# country GRD indicator EN.POP.DNST
# --------------------------
# country GRD indicator ER.H2O.FWST.ZS
# --------------------------
# country GRD indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GRD indicator SP.RUR.TOTL.ZS
# --------------------------
# country GRD indicator CM.MKT.INDX.ZG
# --------------------------
# country GRD indicator VA.NO.SRC
# --------------------------
# country GTM indicator NY.GDP.PCAP.KD
# --------------------------
# country GTM indicator SP.POP.TOTL
# --------------------------
# country GTM indicator SL.UEM.ADVN.ZS
# --------------------------
# country GTM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GTM indicator SI.POV.DDAY
# --------------------------
# country GTM indicator EN.POP.DNST
# --------------------------
# country GTM indicator ER.H2O.FWST.ZS
# --------------------------
# country GTM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GTM indicator SP.RUR.TOTL.ZS
# --------------------------
# country GTM indicator CM.MKT.INDX.ZG
# --------------------------
# country GTM indicator VA.NO.SRC
# --------------------------
# country GIN indicator NY.GDP.PCAP.KD
# --------------------------
# country GIN indicator SP.POP.TOTL
# --------------------------
# country GIN indicator SL.UEM.ADVN.ZS
# --------------------------
# country GIN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GIN indicator SI.POV.DDAY
# --------------------------
# country GIN indicator EN.POP.DNST
# --------------------------
# country GIN indicator ER.H2O.FWST.ZS
# --------------------------
# country GIN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GIN indicator SP.RUR.TOTL.ZS
# --------------------------
# country GIN indicator CM.MKT.INDX.ZG
# --------------------------
# country GIN indicator VA.NO.SRC
# --------------------------
# country GUY indicator NY.GDP.PCAP.KD
# --------------------------
# country GUY indicator SP.POP.TOTL
# --------------------------
# country GUY indicator SL.UEM.ADVN.ZS
# --------------------------
# country GUY indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GUY indicator SI.POV.DDAY
# --------------------------
# country GUY indicator EN.POP.DNST
# --------------------------
# country GUY indicator ER.H2O.FWST.ZS
# --------------------------
# country GUY indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GUY indicator SP.RUR.TOTL.ZS
# --------------------------
# country GUY indicator CM.MKT.INDX.ZG
# --------------------------
# country GUY indicator VA.NO.SRC
# --------------------------
# country HTI indicator NY.GDP.PCAP.KD
# --------------------------
# country HTI indicator SP.POP.TOTL
# --------------------------
# country HTI indicator SL.UEM.ADVN.ZS
# --------------------------
# country HTI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country HTI indicator SI.POV.DDAY
# --------------------------
# country HTI indicator EN.POP.DNST
# --------------------------
# country HTI indicator ER.H2O.FWST.ZS
# --------------------------
# country HTI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country HTI indicator SP.RUR.TOTL.ZS
# --------------------------
# country HTI indicator CM.MKT.INDX.ZG
# --------------------------
# country HTI indicator VA.NO.SRC
# --------------------------
# country HND indicator NY.GDP.PCAP.KD
# --------------------------
# country HND indicator SP.POP.TOTL
# --------------------------
# country HND indicator SL.UEM.ADVN.ZS
# --------------------------
# country HND indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country HND indicator SI.POV.DDAY
# --------------------------
# country HND indicator EN.POP.DNST
# --------------------------
# country HND indicator ER.H2O.FWST.ZS
# --------------------------
# country HND indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country HND indicator SP.RUR.TOTL.ZS
# --------------------------
# country HND indicator CM.MKT.INDX.ZG
# --------------------------
# country HND indicator VA.NO.SRC
# --------------------------
# country HUN indicator NY.GDP.PCAP.KD
# --------------------------
# country HUN indicator SP.POP.TOTL
# --------------------------
# country HUN indicator SL.UEM.ADVN.ZS
# --------------------------
# country HUN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country HUN indicator SI.POV.DDAY
# --------------------------
# country HUN indicator EN.POP.DNST
# --------------------------
# country HUN indicator ER.H2O.FWST.ZS
# --------------------------
# country HUN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country HUN indicator SP.RUR.TOTL.ZS
# --------------------------
# country HUN indicator CM.MKT.INDX.ZG
# --------------------------
# country HUN indicator VA.NO.SRC
# --------------------------
# country ISL indicator NY.GDP.PCAP.KD
# --------------------------
# country ISL indicator SP.POP.TOTL
# --------------------------
# country ISL indicator SL.UEM.ADVN.ZS
# --------------------------
# country ISL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ISL indicator SI.POV.DDAY
# --------------------------
# country ISL indicator EN.POP.DNST
# --------------------------
# country ISL indicator ER.H2O.FWST.ZS
# --------------------------
# country ISL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ISL indicator SP.RUR.TOTL.ZS
# --------------------------
# country ISL indicator CM.MKT.INDX.ZG
# --------------------------
# country ISL indicator VA.NO.SRC
# --------------------------
# country IND indicator NY.GDP.PCAP.KD
# --------------------------
# country IND indicator SP.POP.TOTL
# --------------------------
# country IND indicator SL.UEM.ADVN.ZS
# --------------------------
# country IND indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country IND indicator SI.POV.DDAY
# --------------------------
# country IND indicator EN.POP.DNST
# --------------------------
# country IND indicator ER.H2O.FWST.ZS
# --------------------------
# country IND indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country IND indicator SP.RUR.TOTL.ZS
# --------------------------
# country IND indicator CM.MKT.INDX.ZG
# --------------------------
# country IND indicator VA.NO.SRC
# --------------------------
# country IDN indicator NY.GDP.PCAP.KD
# --------------------------
# country IDN indicator SP.POP.TOTL
# --------------------------
# country IDN indicator SL.UEM.ADVN.ZS
# --------------------------
# country IDN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country IDN indicator SI.POV.DDAY
# --------------------------
# country IDN indicator EN.POP.DNST
# --------------------------
# country IDN indicator ER.H2O.FWST.ZS
# --------------------------
# country IDN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country IDN indicator SP.RUR.TOTL.ZS
# --------------------------
# country IDN indicator CM.MKT.INDX.ZG
# --------------------------
# country IDN indicator VA.NO.SRC
# --------------------------
# country IRQ indicator NY.GDP.PCAP.KD
# --------------------------
# country IRQ indicator SP.POP.TOTL
# --------------------------
# country IRQ indicator SL.UEM.ADVN.ZS
# --------------------------
# country IRQ indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country IRQ indicator SI.POV.DDAY
# --------------------------
# country IRQ indicator EN.POP.DNST
# --------------------------
# country IRQ indicator ER.H2O.FWST.ZS
# --------------------------
# country IRQ indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country IRQ indicator SP.RUR.TOTL.ZS
# --------------------------
# country IRQ indicator CM.MKT.INDX.ZG
# --------------------------
# country IRQ indicator VA.NO.SRC
# --------------------------
# country IRL indicator NY.GDP.PCAP.KD
# --------------------------
# country IRL indicator SP.POP.TOTL
# --------------------------
# country IRL indicator SL.UEM.ADVN.ZS
# --------------------------
# country IRL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country IRL indicator SI.POV.DDAY
# --------------------------
# country IRL indicator EN.POP.DNST
# --------------------------
# country IRL indicator ER.H2O.FWST.ZS
# --------------------------
# country IRL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country IRL indicator SP.RUR.TOTL.ZS
# --------------------------
# country IRL indicator CM.MKT.INDX.ZG
# --------------------------
# country IRL indicator VA.NO.SRC
# --------------------------
# country ISR indicator NY.GDP.PCAP.KD
# --------------------------
# country ISR indicator SP.POP.TOTL
# --------------------------
# country ISR indicator SL.UEM.ADVN.ZS
# --------------------------
# country ISR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ISR indicator SI.POV.DDAY
# --------------------------
# country ISR indicator EN.POP.DNST
# --------------------------
# country ISR indicator ER.H2O.FWST.ZS
# --------------------------
# country ISR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ISR indicator SP.RUR.TOTL.ZS
# --------------------------
# country ISR indicator CM.MKT.INDX.ZG
# --------------------------
# country ISR indicator VA.NO.SRC
# --------------------------
# country ITA indicator NY.GDP.PCAP.KD
# --------------------------
# country ITA indicator SP.POP.TOTL
# --------------------------
# country ITA indicator SL.UEM.ADVN.ZS
# --------------------------
# country ITA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ITA indicator SI.POV.DDAY
# --------------------------
# country ITA indicator EN.POP.DNST
# --------------------------
# country ITA indicator ER.H2O.FWST.ZS
# --------------------------
# country ITA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ITA indicator SP.RUR.TOTL.ZS
# --------------------------
# country ITA indicator CM.MKT.INDX.ZG
# --------------------------
# country ITA indicator VA.NO.SRC
# --------------------------
# country JAM indicator NY.GDP.PCAP.KD
# --------------------------
# country JAM indicator SP.POP.TOTL
# --------------------------
# country JAM indicator SL.UEM.ADVN.ZS
# --------------------------
# country JAM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country JAM indicator SI.POV.DDAY
# --------------------------
# country JAM indicator EN.POP.DNST
# --------------------------
# country JAM indicator ER.H2O.FWST.ZS
# --------------------------
# country JAM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country JAM indicator SP.RUR.TOTL.ZS
# --------------------------
# country JAM indicator CM.MKT.INDX.ZG
# --------------------------
# country JAM indicator VA.NO.SRC
# --------------------------
# country JPN indicator NY.GDP.PCAP.KD
# --------------------------
# country JPN indicator SP.POP.TOTL
# --------------------------
# country JPN indicator SL.UEM.ADVN.ZS
# --------------------------
# country JPN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country JPN indicator SI.POV.DDAY
# --------------------------
# country JPN indicator EN.POP.DNST
# --------------------------
# country JPN indicator ER.H2O.FWST.ZS
# --------------------------
# country JPN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country JPN indicator SP.RUR.TOTL.ZS
# --------------------------
# country JPN indicator CM.MKT.INDX.ZG
# --------------------------
# country JPN indicator VA.NO.SRC
# --------------------------
# country JOR indicator NY.GDP.PCAP.KD
# --------------------------
# country JOR indicator SP.POP.TOTL
# --------------------------
# country JOR indicator SL.UEM.ADVN.ZS
# --------------------------
# country JOR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country JOR indicator SI.POV.DDAY
# --------------------------
# country JOR indicator EN.POP.DNST
# --------------------------
# country JOR indicator ER.H2O.FWST.ZS
# --------------------------
# country JOR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country JOR indicator SP.RUR.TOTL.ZS
# --------------------------
# country JOR indicator CM.MKT.INDX.ZG
# --------------------------
# country JOR indicator VA.NO.SRC
# --------------------------
# country KAZ indicator NY.GDP.PCAP.KD
# --------------------------
# country KAZ indicator SP.POP.TOTL
# --------------------------
# country KAZ indicator SL.UEM.ADVN.ZS
# --------------------------
# country KAZ indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country KAZ indicator SI.POV.DDAY
# --------------------------
# country KAZ indicator EN.POP.DNST
# --------------------------
# country KAZ indicator ER.H2O.FWST.ZS
# --------------------------
# country KAZ indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country KAZ indicator SP.RUR.TOTL.ZS
# --------------------------
# country KAZ indicator CM.MKT.INDX.ZG
# --------------------------
# country KAZ indicator VA.NO.SRC
# --------------------------
# country KEN indicator NY.GDP.PCAP.KD
# --------------------------
# country KEN indicator SP.POP.TOTL
# --------------------------
# country KEN indicator SL.UEM.ADVN.ZS
# --------------------------
# country KEN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country KEN indicator SI.POV.DDAY
# --------------------------
# country KEN indicator EN.POP.DNST
# --------------------------
# country KEN indicator ER.H2O.FWST.ZS
# --------------------------
# country KEN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country KEN indicator SP.RUR.TOTL.ZS
# --------------------------
# country KEN indicator CM.MKT.INDX.ZG
# --------------------------
# country KEN indicator VA.NO.SRC
# --------------------------
# country XKX indicator NY.GDP.PCAP.KD
# --------------------------
# country XKX indicator SP.POP.TOTL
# --------------------------
# country XKX indicator SL.UEM.ADVN.ZS
# --------------------------
# country XKX indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country XKX indicator SI.POV.DDAY
# --------------------------
# country XKX indicator EN.POP.DNST
# --------------------------
# country XKX indicator ER.H2O.FWST.ZS
# --------------------------
# country XKX indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country XKX indicator SP.RUR.TOTL.ZS
# --------------------------
# ...
# country TKM indicator NY.GDP.PCAP.KD
# --------------------------
# country TKM indicator SP.POP.TOTL
# --------------------------
# country TKM indicator SL.UEM.ADVN.ZS
# --------------------------
# country TKM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country TKM indicator SI.POV.DDAY
# --------------------------
# country TKM indicator EN.POP.DNST
# --------------------------
# country TKM indicator ER.H2O.FWST.ZS
# --------------------------
# country TKM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country TKM indicator SP.RUR.TOTL.ZS
# --------------------------
# country TKM indicator CM.MKT.INDX.ZG
# --------------------------
# country TKM indicator VA.NO.SRC
# --------------------------
# country PNG indicator NY.GDP.PCAP.KD
# --------------------------
# country PNG indicator SP.POP.TOTL
# --------------------------
# country PNG indicator SL.UEM.ADVN.ZS
# --------------------------
# country PNG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country PNG indicator SI.POV.DDAY
# --------------------------
# country PNG indicator EN.POP.DNST
# --------------------------
# country PNG indicator ER.H2O.FWST.ZS
# --------------------------
# country PNG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country PNG indicator SP.RUR.TOTL.ZS
# --------------------------
# country PNG indicator CM.MKT.INDX.ZG
# --------------------------
# country PNG indicator VA.NO.SRC
# --------------------------
# country ARE indicator NY.GDP.PCAP.KD
# --------------------------
# country ARE indicator SP.POP.TOTL
# --------------------------
# country ARE indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARE indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ARE indicator SI.POV.DDAY
# --------------------------
# country ARE indicator EN.POP.DNST
# --------------------------
# country ARE indicator ER.H2O.FWST.ZS
# --------------------------
# country ARE indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ARE indicator SP.RUR.TOTL.ZS
# --------------------------
# country ARE indicator CM.MKT.INDX.ZG
# --------------------------
# country ARE indicator VA.NO.SRC
# --------------------------
# country QAT indicator NY.GDP.PCAP.KD
# --------------------------
# country QAT indicator SP.POP.TOTL
# --------------------------
# country QAT indicator SL.UEM.ADVN.ZS
# --------------------------
# country QAT indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country QAT indicator SI.POV.DDAY
# --------------------------
# country QAT indicator EN.POP.DNST
# --------------------------
# country QAT indicator ER.H2O.FWST.ZS
# --------------------------
# country QAT indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country QAT indicator SP.RUR.TOTL.ZS
# --------------------------
# country QAT indicator CM.MKT.INDX.ZG
# --------------------------
# country QAT indicator VA.NO.SRC
# --------------------------
# country LSO indicator NY.GDP.PCAP.KD
# --------------------------
# country LSO indicator SP.POP.TOTL
# --------------------------
# country LSO indicator SL.UEM.ADVN.ZS
# --------------------------
# country LSO indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country LSO indicator SI.POV.DDAY
# --------------------------
# country LSO indicator EN.POP.DNST
# --------------------------
# country LSO indicator ER.H2O.FWST.ZS
# --------------------------
# country LSO indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country LSO indicator SP.RUR.TOTL.ZS
# --------------------------
# country LSO indicator CM.MKT.INDX.ZG
# --------------------------
# country LSO indicator VA.NO.SRC
# --------------------------
# country MCO indicator NY.GDP.PCAP.KD
# --------------------------
# country MCO indicator SP.POP.TOTL
# --------------------------
# country MCO indicator SL.UEM.ADVN.ZS
# --------------------------
# country MCO indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country MCO indicator SI.POV.DDAY
# --------------------------
# country MCO indicator EN.POP.DNST
# --------------------------
# country MCO indicator ER.H2O.FWST.ZS
# --------------------------
# country MCO indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country MCO indicator SP.RUR.TOTL.ZS
# --------------------------
# country MCO indicator CM.MKT.INDX.ZG
# --------------------------
# country MCO indicator VA.NO.SRC
# --------------------------
# country SYC indicator NY.GDP.PCAP.KD
# --------------------------
# country SYC indicator SP.POP.TOTL
# --------------------------
# country SYC indicator SL.UEM.ADVN.ZS
# --------------------------
# country SYC indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country SYC indicator SI.POV.DDAY
# --------------------------
# country SYC indicator EN.POP.DNST
# --------------------------
# country SYC indicator ER.H2O.FWST.ZS
# --------------------------
# country SYC indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country SYC indicator SP.RUR.TOTL.ZS
# --------------------------
# country SYC indicator CM.MKT.INDX.ZG
# --------------------------
# country SYC indicator VA.NO.SRC
# --------------------------
# country GNQ indicator NY.GDP.PCAP.KD
# --------------------------
# country GNQ indicator SP.POP.TOTL
# --------------------------
# country GNQ indicator SL.UEM.ADVN.ZS
# --------------------------
# country GNQ indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country GNQ indicator SI.POV.DDAY
# --------------------------
# country GNQ indicator EN.POP.DNST
# --------------------------
# country GNQ indicator ER.H2O.FWST.ZS
# --------------------------
# country GNQ indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country GNQ indicator SP.RUR.TOTL.ZS
# --------------------------
# country GNQ indicator CM.MKT.INDX.ZG
# --------------------------
# country GNQ indicator VA.NO.SRC
# --------------------------
# country KIR indicator NY.GDP.PCAP.KD
# --------------------------
# country KIR indicator SP.POP.TOTL
# --------------------------
# country KIR indicator SL.UEM.ADVN.ZS
# --------------------------
# country KIR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country KIR indicator SI.POV.DDAY
# --------------------------
# country KIR indicator EN.POP.DNST
# --------------------------
# country KIR indicator ER.H2O.FWST.ZS
# --------------------------
# country KIR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country KIR indicator SP.RUR.TOTL.ZS
# --------------------------
# country KIR indicator CM.MKT.INDX.ZG
# --------------------------
# country KIR indicator VA.NO.SRC
# --------------------------
# country SMR indicator NY.GDP.PCAP.KD
# --------------------------
# country SMR indicator SP.POP.TOTL
# --------------------------
# country SMR indicator SL.UEM.ADVN.ZS
# --------------------------
# country SMR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country SMR indicator SI.POV.DDAY
# --------------------------
# country SMR indicator EN.POP.DNST
# --------------------------
# country SMR indicator ER.H2O.FWST.ZS
# --------------------------
# country SMR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country SMR indicator SP.RUR.TOTL.ZS
# --------------------------
# country SMR indicator CM.MKT.INDX.ZG
# --------------------------
# country SMR indicator VA.NO.SRC
# --------------------------
# country PLW indicator NY.GDP.PCAP.KD
# --------------------------
# country PLW indicator SP.POP.TOTL
# --------------------------
# country PLW indicator SL.UEM.ADVN.ZS
# --------------------------
# country PLW indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country PLW indicator SI.POV.DDAY
# --------------------------
# country PLW indicator EN.POP.DNST
# --------------------------
# country PLW indicator ER.H2O.FWST.ZS
# --------------------------
# country PLW indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country PLW indicator SP.RUR.TOTL.ZS
# --------------------------
# country PLW indicator CM.MKT.INDX.ZG
# --------------------------
# country PLW indicator VA.NO.SRC
# --------------------------
# country MHL indicator NY.GDP.PCAP.KD
# --------------------------
# country MHL indicator SP.POP.TOTL
# --------------------------
# country MHL indicator SL.UEM.ADVN.ZS
# --------------------------
# country MHL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country MHL indicator SI.POV.DDAY
# --------------------------
# country MHL indicator EN.POP.DNST
# --------------------------
# country MHL indicator ER.H2O.FWST.ZS
# --------------------------
# country MHL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country MHL indicator SP.RUR.TOTL.ZS
# --------------------------
# country MHL indicator CM.MKT.INDX.ZG
# --------------------------
# country MHL indicator VA.NO.SRC
# --------------------------
# country BMU indicator NY.GDP.PCAP.KD
# --------------------------
# country BMU indicator SP.POP.TOTL
# --------------------------
# country BMU indicator SL.UEM.ADVN.ZS
# --------------------------
# country BMU indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BMU indicator SI.POV.DDAY
# --------------------------
# country BMU indicator EN.POP.DNST
# --------------------------
# country BMU indicator ER.H2O.FWST.ZS
# --------------------------
# country BMU indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BMU indicator SP.RUR.TOTL.ZS
# --------------------------
# country BMU indicator CM.MKT.INDX.ZG
# --------------------------
# country BMU indicator VA.NO.SRC
# --------------------------
# country NCL indicator NY.GDP.PCAP.KD
# --------------------------
# country NCL indicator SP.POP.TOTL
# --------------------------
# country NCL indicator SL.UEM.ADVN.ZS
# --------------------------
# country NCL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country NCL indicator SI.POV.DDAY
# --------------------------
# country NCL indicator EN.POP.DNST
# --------------------------
# country NCL indicator ER.H2O.FWST.ZS
# --------------------------
# country NCL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country NCL indicator SP.RUR.TOTL.ZS
# --------------------------
# country NCL indicator CM.MKT.INDX.ZG
# --------------------------
# country NCL indicator VA.NO.SRC
# --------------------------
# country MNP indicator NY.GDP.PCAP.KD
# --------------------------
# country MNP indicator SP.POP.TOTL
# --------------------------
# country MNP indicator SL.UEM.ADVN.ZS
# --------------------------
# country MNP indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country MNP indicator SI.POV.DDAY
# --------------------------
# country MNP indicator EN.POP.DNST
# --------------------------
# country MNP indicator ER.H2O.FWST.ZS
# --------------------------
# country MNP indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country MNP indicator SP.RUR.TOTL.ZS
# --------------------------
# country MNP indicator CM.MKT.INDX.ZG
# --------------------------
# country MNP indicator VA.NO.SRC
# --------------------------
# country CUW indicator NY.GDP.PCAP.KD
# --------------------------
# country CUW indicator SP.POP.TOTL
# --------------------------
# country CUW indicator SL.UEM.ADVN.ZS
# --------------------------
# country CUW indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CUW indicator SI.POV.DDAY
# --------------------------
# country CUW indicator EN.POP.DNST
# --------------------------
# country CUW indicator ER.H2O.FWST.ZS
# --------------------------
# country CUW indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CUW indicator SP.RUR.TOTL.ZS
# --------------------------
# country CUW indicator CM.MKT.INDX.ZG
# --------------------------
# country CUW indicator VA.NO.SRC
# --------------------------
# country TUV indicator NY.GDP.PCAP.KD
# --------------------------
# country TUV indicator SP.POP.TOTL
# --------------------------
# country TUV indicator SL.UEM.ADVN.ZS
# --------------------------
# country TUV indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country TUV indicator SI.POV.DDAY
# --------------------------
# country TUV indicator EN.POP.DNST
# --------------------------
# country TUV indicator ER.H2O.FWST.ZS
# --------------------------
# country TUV indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country TUV indicator SP.RUR.TOTL.ZS
# --------------------------
# country TUV indicator CM.MKT.INDX.ZG
# --------------------------
# country TUV indicator VA.NO.SRC
# --------------------------
# country LIE indicator NY.GDP.PCAP.KD
# --------------------------
# country LIE indicator SP.POP.TOTL
# --------------------------
# country LIE indicator SL.UEM.ADVN.ZS
# --------------------------
# country LIE indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country LIE indicator SI.POV.DDAY
# --------------------------
# country LIE indicator EN.POP.DNST
# --------------------------
# country LIE indicator ER.H2O.FWST.ZS
# --------------------------
# country LIE indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country LIE indicator SP.RUR.TOTL.ZS
# --------------------------
# country LIE indicator CM.MKT.INDX.ZG
# --------------------------
# country LIE indicator VA.NO.SRC
# --------------------------
# country PRI indicator NY.GDP.PCAP.KD
# --------------------------
# country PRI indicator SP.POP.TOTL
# --------------------------
# country PRI indicator SL.UEM.ADVN.ZS
# --------------------------
# country PRI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country PRI indicator SI.POV.DDAY
# --------------------------
# country PRI indicator EN.POP.DNST
# --------------------------
# country PRI indicator ER.H2O.FWST.ZS
# --------------------------
# country PRI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country PRI indicator SP.RUR.TOTL.ZS
# --------------------------
# country PRI indicator CM.MKT.INDX.ZG
# --------------------------
# country PRI indicator VA.NO.SRC
# --------------------------
# country PYF indicator NY.GDP.PCAP.KD
# --------------------------
# country PYF indicator SP.POP.TOTL
# --------------------------
# country PYF indicator SL.UEM.ADVN.ZS
# --------------------------
# country PYF indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country PYF indicator SI.POV.DDAY
# --------------------------
# country PYF indicator EN.POP.DNST
# --------------------------
# country PYF indicator ER.H2O.FWST.ZS
# --------------------------
# country PYF indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country PYF indicator SP.RUR.TOTL.ZS
# --------------------------
# country PYF indicator CM.MKT.INDX.ZG
# --------------------------
# country PYF indicator VA.NO.SRC
# --------------------------
# country NRU indicator NY.GDP.PCAP.KD
# --------------------------
# country NRU indicator SP.POP.TOTL
# --------------------------
# country NRU indicator SL.UEM.ADVN.ZS
# --------------------------
# country NRU indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country NRU indicator SI.POV.DDAY
# --------------------------
# country NRU indicator EN.POP.DNST
# --------------------------
# country NRU indicator ER.H2O.FWST.ZS
# --------------------------
# country NRU indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country NRU indicator SP.RUR.TOTL.ZS
# --------------------------
# country NRU indicator CM.MKT.INDX.ZG
# --------------------------
# country NRU indicator VA.NO.SRC
# --------------------------
# country STP indicator NY.GDP.PCAP.KD
# --------------------------
# country STP indicator SP.POP.TOTL
# --------------------------
# country STP indicator SL.UEM.ADVN.ZS
# --------------------------
# country STP indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country STP indicator SI.POV.DDAY
# --------------------------
# country STP indicator EN.POP.DNST
# --------------------------
# country STP indicator ER.H2O.FWST.ZS
# --------------------------
# country STP indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country STP indicator SP.RUR.TOTL.ZS
# --------------------------
# country STP indicator CM.MKT.INDX.ZG
# --------------------------
# country STP indicator VA.NO.SRC
# --------------------------
# country VUT indicator NY.GDP.PCAP.KD
# --------------------------
# country VUT indicator SP.POP.TOTL
# --------------------------
# country VUT indicator SL.UEM.ADVN.ZS
# --------------------------
# country VUT indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country VUT indicator SI.POV.DDAY
# --------------------------
# country VUT indicator EN.POP.DNST
# --------------------------
# country VUT indicator ER.H2O.FWST.ZS
# --------------------------
# country VUT indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country VUT indicator SP.RUR.TOTL.ZS
# --------------------------
# country VUT indicator CM.MKT.INDX.ZG
# --------------------------
# country VUT indicator VA.NO.SRC

# %%
## Create DF with the previous output

macro_eco_data_df = pd.DataFrame(macro_eco_data_list)
macro_eco_data_df = macro_eco_data_df.dropna(how='all')

macro_eco_data_df.head()
# Out:
#   iso3Code iso2Code      country  year                           indicator  \
# 0      AFG       AF  Afghanistan  2023  GDP per capita (constant 2015 US$)
# 1      AFG       AF  Afghanistan  2022  GDP per capita (constant 2015 US$)
# 2      AFG       AF  Afghanistan  2021  GDP per capita (constant 2015 US$)
# 3      AFG       AF  Afghanistan  2020  GDP per capita (constant 2015 US$)
# 4      AFG       AF  Afghanistan  2019  GDP per capita (constant 2015 US$)
#
#         value
# 0  379.707497
# 1  377.665627
# 2  408.625855
# 3  527.834554
# 4  557.861533

# %%
print(f'size of the DF : {macro_eco_data_df.shape}')
print('................')
print(macro_eco_data_df.dtypes)
# Out:
# size of the DF : (16533, 6)
# ................
# iso3Code      object
# iso2Code      object
# country       object
# year          object
# indicator     object
# value        float64
# dtype: object

# %%
# change datatype 

macro_eco_data_df = macro_eco_data_df.astype({'year':'int64'})
macro_eco_data_df.dtypes
# Out:
# iso3Code      object
# iso2Code      object
# Country       object
# year           int64
# indicator     object
# value        float64
# dtype: object

# %%
# export to csv

macro_eco_data_df.to_csv('Output/macro_economic_data.csv')
