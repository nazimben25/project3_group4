# %%
## Dependencies

import pandas as pd
import pathlib as path



import requests
import json
from pprint import pprint

import numpy as np
from scipy.stats import linregress

from io import StringIO

# import matplotlib.pyplot as plt
# import hvplot.pandas
# import geopandas as gpd

# %% [markdown]
# # (1) create DF for countries
#
# #### information will be used to merge or generate vizualisations
# source : https://api.worldbank.org/v2/country?format=json

# %%
## retrieve all the countries from world bank API

### generate DF Countries

page = 1   ## there are 6 pages in the json file
data = []
url_countries = 'https://api.worldbank.org/v2/country?format=json'

for page in range(1,7):
    response = requests.get(f"{url_countries}&page={page}")
    json_data = response.json()
    
    # Add the data from the current page
    data.extend(json_data[1])  
    
## create DF and select columns

countries_wb_df = pd.DataFrame(data)
countries_wb_df['region'] = countries_wb_df['region'].apply(lambda x: x['value'])
countries_wb_df = countries_wb_df[['id', 'iso2Code', 'name', 'region','capitalCity', 'longitude', 'latitude']]
countries_wb_df = countries_wb_df.rename(columns={
                                                    'name':'country',
                                                    'id':'iso3Code'
                                                    })


regions = (countries_wb_df['region'] != "Aggregates")
countries_wb_df = countries_wb_df[regions]


countries_wb_df.head()
# Out:
#   iso3Code iso2Code      country                      region  \
# 0      ABW       AW        Aruba  Latin America & Caribbean
# 2      AFG       AF  Afghanistan                  South Asia
# 5      AGO       AO       Angola         Sub-Saharan Africa
# 6      ALB       AL      Albania       Europe & Central Asia
# 7      AND       AD      Andorra       Europe & Central Asia
#
#         capitalCity longitude  latitude
# 0        Oranjestad  -70.0167   12.5167
# 2             Kabul   69.1761   34.5228
# 5            Luanda    13.242  -8.81155
# 6            Tirane   19.8172   41.3317
# 7  Andorra la Vella    1.5218   42.5075

# %%
countries_wb_df = countries_wb_df.set_index('iso3Code')
countries_wb_df
# Out:
#          iso2Code       country                      region       capitalCity  \
# iso3Code
# ABW            AW         Aruba  Latin America & Caribbean         Oranjestad
# AFG            AF   Afghanistan                  South Asia             Kabul
# AGO            AO        Angola         Sub-Saharan Africa             Luanda
# ALB            AL       Albania       Europe & Central Asia            Tirane
# AND            AD       Andorra       Europe & Central Asia  Andorra la Vella
# ...           ...           ...                         ...               ...
# XKX            XK        Kosovo       Europe & Central Asia          Pristina
# YEM            YE   Yemen, Rep.  Middle East & North Africa            Sana'a
# ZAF            ZA  South Africa         Sub-Saharan Africa           Pretoria
# ZMB            ZM        Zambia         Sub-Saharan Africa             Lusaka
# ZWE            ZW      Zimbabwe         Sub-Saharan Africa             Harare
#
#          longitude  latitude
# iso3Code
# ABW       -70.0167   12.5167
# AFG        69.1761   34.5228
# AGO         13.242  -8.81155
# ALB        19.8172   41.3317
# AND         1.5218   42.5075
# ...            ...       ...
# XKX         20.926    42.565
# YEM        44.2075    15.352
# ZAF        28.1871   -25.746
# ZMB        28.2937  -15.3982
# ZWE        31.0672  -17.8312
#
# [217 rows x 6 columns]

# %%
### Export to csv file in output

countries_wb_df.to_csv('Output/countries_list_UN_referential.csv')

# %%
countries_wb_df = countries_wb_df.reset_index()

# %% [markdown]
# # (2) collect immigration data

# %% [markdown]
# ##### Data source from IRCC web site
# https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv
# from
# https://ouvert.canada.ca/data/fr/dataset/f7e5498e-0ad8-4417-85c9-9b8aff9b9eda/resource/5f5fa9ca-b621-4dac-91d1-25654a25735c

# %%
# # Define the path to your CSV file
# path_imm = 'https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv'

# # Fetch the CSV file content
# response = requests.get(path_imm)
# response.raise_for_status()  # Check if the request was successful

# # Decode the content from binary to text
# content = response.content.decode('utf-8')

# # Use StringIO to read the content as if it were a file
# content_io = StringIO(content)

# # Read the CSV file into a DataFrame using pandas
# imm_df = pd.read_csv(content_io, delimiter='\t', dtype=str)

# %%
# imm_df.head(5)

# %%
### import and read csv file

path_imm = 'https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv'
imm_df = pd.read_csv(path_imm, delimiter='\t')

imm_df.to_csv('Resources/immigration_raw_data.csv')
imm_df.head(5)
# Out:
#    EN_YEAR EN_QUARTER EN_MONTH  FR_ANNEÉ FR_TRIMESTRE FR_MOIS  \
# 0     2015         Q1      Feb      2015           T1    fév.
# 1     2015         Q1      Feb      2015           T1    fév.
# 2     2015         Q1      Feb      2015           T1    fév.
# 3     2015         Q1      Feb      2015           T1    fév.
# 4     2015         Q1      Feb      2015           T1    fév.
#
#   EN_COUNTRY_OF_CITIZENSHIP FR_PAYS_DE_CITOYENNETÉ TOTAL
# 0               Afghanistan            Afghanistan   125
# 1                   Albania                Albanie    25
# 2                   Algeria                Algérie   125
# 3       Antigua and Barbuda     Antigua-et-Barbuda     5
# 4                 Argentina              Argentine    15

# %%
# drop useless columns

imm_df = imm_df.drop(columns=['FR_ANNEÉ','FR_TRIMESTRE','FR_MOIS','FR_PAYS_DE_CITOYENNETÉ'])
imm_df.head(5)
# Out:
#    EN_YEAR EN_QUARTER EN_MONTH EN_COUNTRY_OF_CITIZENSHIP TOTAL
# 0     2015         Q1      Feb               Afghanistan   125
# 1     2015         Q1      Feb                   Albania    25
# 2     2015         Q1      Feb                   Algeria   125
# 3     2015         Q1      Feb       Antigua and Barbuda     5
# 4     2015         Q1      Feb                 Argentina    15

# %%
# check empty values with 1 example raw 42

print(imm_df.loc[42,])
# Out:
# EN_YEAR                          2015
# EN_QUARTER                         Q1
# EN_MONTH                          Feb
# EN_COUNTRY_OF_CITIZENSHIP    Dominica
# TOTAL                              --
# Name: 42, dtype: object

# %%
imm_clean_df = imm_df.copy()

# %%
# convert Total to numeric

imm_clean_df['TOTAL'] = pd.to_numeric(imm_clean_df['TOTAL'], errors='coerce')

# replace NAN with 0 and change data type

imm_clean_df = imm_clean_df.fillna({'TOTAL': 0})
imm_clean_df = imm_clean_df.astype({'TOTAL': 'int64'})
print(imm_clean_df.loc[42,])
# Out:
# EN_YEAR                          2015
# EN_QUARTER                         Q1
# EN_MONTH                          Feb
# EN_COUNTRY_OF_CITIZENSHIP    Dominica
# TOTAL                               0
# Name: 42, dtype: object

# %%
# check that total is numeric _ integer

imm_clean_df.dtypes
# Out:
# EN_YEAR                       int64
# EN_QUARTER                   object
# EN_MONTH                     object
# EN_COUNTRY_OF_CITIZENSHIP    object
# TOTAL                         int64
# dtype: object

# %%
# rename columns 

imm_clean_df = imm_clean_df.rename(columns={
                                            'EN_YEAR'            :           'year' ,
                                            'EN_QUARTER'         :          'quarter' , 
                                            'EN_MONTH'           :          'month_str' ,
                                            'EN_COUNTRY_OF_CITIZENSHIP' :   'country' ,  # will be splitted and replaced
                                            'TOTAL'              :           'immigration_flow'
                                            })
imm_clean_df.dtypes
# Out:
# year                 int64
# quarter             object
# month_str           object
# country             object
# immigration_flow     int64
# dtype: object

# %%
# to identify the countries names that mismatch between IRCC and World bank

countries_wb = pd.DataFrame(countries_wb_df['country'].unique() , columns=['country'])
countries_ircc = pd.DataFrame(imm_clean_df['country'].unique(),  columns=['country'])

# Add a source column to indicate the origin
countries_wb['source'] = 'countries_wb'
countries_ircc['source'] = 'countries_ircc'

# Concatenate the two DataFrames
all_countries = pd.concat([countries_wb, countries_ircc], ignore_index=True)

# Find non-corresponding values
non_corresponding_values = all_countries.groupby('country').filter(lambda x: len(x) == 1)

# Display the non-corresponding values with their origin
print(non_corresponding_values)
non_corresponding_values.to_csv('Output/non_corresponding_countries.csv')
# Out:
#             country          source
# 0             Aruba    countries_wb
# 8    American Samoa    countries_wb
# 15            Benin    countries_wb
# 16     Burkina Faso    countries_wb
# 20     Bahamas, The    countries_wb
# ..              ...             ...
# 423        Holy See  countries_ircc
# 424          Azores  countries_ircc
# 427      Guadeloupe  countries_ircc
# 431         Reunion  countries_ircc
# 432    Sint-Maarten  countries_ircc
#
# [159 rows x 2 columns]

# %%
# Change countries name to match to th United Nations standard

imm_clean_df['country'] = imm_clean_df['country'].replace({
                            
                                    'Azores'  :  'Canada' ,
                                    'Bahama Islands, The'  :  'Bahamas, The' ,
                                    'Benin, Republic of'  :  'Benin' ,
                                    'Bosnia-Herzegovina'  :  'Bosnia and Herzegovina' ,
                                    'Botswana, Republic of'  :  'Botswana' ,
                                    'Brunei'  :  'Brunei Darussalam' ,
                                    'Burkina-Faso'  :  'Burkina Faso' ,
                                    'Cameroon, Federal Republic of'  :  'Cameroon' ,
                                    'Cape Verde Islands'  :  'Cabo Verde' ,
                                    'Chad, Republic of'  :  'Chad' ,
                                    "China, People's Republic of"  :  'China' ,
                                    'Congo, Democratic Republic of the'  :  'Congo, Dem. Rep.' ,
                                    "Congo, People's Republic of the"  :  'Congo, Rep.' ,
                                    'Country not stated'  :  'Canada' ,
                                    'Czech Republic'  :  'Czechia' ,
                                    'Djibouti, Republic of'  :  'Djibouti' ,
                                    'East Timor, Democratic Republic of'  :  'Timor-Leste' ,
                                    'Egypt'  :  'Egypt, Arab Rep.' ,
                                    'Equatorial Guinea, Republic of'  :  'Equatorial Guinea' ,
                                    'Gabon Republic'  :  'Gabon' ,
                                    'Gambia'  :  'Gambia, The' ,
                                    'Guadeloupe'  :  'France' ,
                                    'Guinea, Republic of'  :  'Guinea' ,
                                    'Holy See'  :  'Canada' ,
                                    'Hong Kong SAR'  :  'Hong Kong SAR, China' ,
                                    'Indonesia, Republic of'  :  'Indonesia' ,
                                    'Iran'  :  'Iran, Islamic Rep.' ,
                                    'Ireland, Republic of'  :  'Ireland' ,
                                    'Ivory Coast, Republic of'  :  "Cote d'Ivoire" ,
                                    "Korea, People's Democratic Republic of"  :  "Korea, Dem. People's Rep." ,
                                    'Korea, Republic of'  :  'Korea, Rep.' ,
                                    'Kosovo, Republic of'  :  'Kosovo' ,
                                    'Kyrgyzstan'  :  'Kyrgyz Republic' ,
                                    'Laos'  :  'Lao PDR' ,
                                    'Macau SAR'  :  'Macao SAR, China' ,
                                    'Macedonia'  :  'North Macedonia' ,
                                    'Maldives, Republic of'  :  'Maldives' ,
                                    'Mali, Republic of'  :  'Mali' ,
                                    'Marshall Islands, Republic of the'  :  'Marshall Islands' ,
                                    'Micronesia, Federated States of'  :  'Canada' ,
                                    "Mongolia, People's Republic of"  :  'Mongolia' ,
                                    'Montenegro, Republic of'  :  'Montenegro' ,
                                    'Myanmar (Burma)'  :  'Myanmar' ,
                                    'Netherlands Antilles, The'  :  'Canada' ,
                                    'Netherlands, The'  :  'Netherlands' ,
                                    'Nevis'  :  'Canada' ,
                                    'Niger, Republic of the'  :  'Niger' ,
                                    'Northern Mariana Islands, Commonwealth of the'  :  'Northern Mariana Islands' ,
                                    'Other'  :  'Canada' ,
                                    'Palau, Republic of'  :  'Palau' ,
                                    'Palestinian Authority (Gaza/West Bank)'  :  'West Bank and Gaza' ,
                                    'Panama, Republic of'  :  'Panama' ,
                                    'Reunion'  :  'France' ,
                                    'Russia'  :  'Russian Federation' ,
                                    'Samoa, American'  :  'Samoa' ,
                                    'Samoa, Independent State of'  :  'American Samoa' ,
                                    'Serbia, Republic of'  :  'Serbia' ,
                                    'Sint-Maarten'  :  'Sint Maarten (Dutch part)' ,
                                    'Somalia, Democratic Republic of'  :  'Somalia' ,
                                    'South Africa, Republic of'  :  'South Africa' ,
                                    'South Sudan, Republic of'  :  'South Sudan' ,
                                    'St. Kitts-Nevis'  :  'Canada' ,
                                    'Stateless'  :  'Canada' ,
                                    'Sudan, Democratic Republic of'  :  'Sudan' ,
                                    'Surinam'  :  'Suriname' ,
                                    'Swaziland'  :  'Somalia' ,
                                    'Syria'  :  'Syrian Arab Republic' ,
                                    'Taiwan'  :  'China' ,
                                    'Tanzania, United Republic of'  :  'Tanzania' ,
                                    'Togo, Republic of'  :  'Togo' ,
                                    'Trinidad and Tobago, Republic of'  :  'Trinidad and Tobago' ,
                                    'Turkey'  :  'Turkiye' ,
                                    'United Kingdom and Overseas Territories'  :  'United Kingdom' ,
                                    'United States of America'  :  'United States' ,
                                    'Venezuela'  :  'Venezuela, RB' ,
                                    'Vietnam'  :  'Viet Nam' ,
                                    'Virgin Islands, British'  :  'British Virgin Islands' ,
                                    'Western Sahara'  :  'Canada' ,
                                    'Yemen'  :  'Yemen, Rep.' ,


                                     })

# %%
countries_wb = pd.DataFrame(countries_wb_df['country'].unique() , columns=['country'])
countries_ircc = pd.DataFrame(imm_clean_df['country'].unique(),  columns=['country'])

# Add a source column to indicate the origin
countries_wb['source'] = 'countries_wb'
countries_ircc['source'] = 'countries_ircc'

# Concatenate the two DataFrames
all_countries = pd.concat([countries_wb, countries_ircc], ignore_index=True)

# Find non-corresponding values
non_corresponding_values = all_countries.groupby('country').filter(lambda x: len(x) == 1)

# Display the non-corresponding values with their origin
print(non_corresponding_values)  ## you must have only countries_wb source
# Out:
#                       country        source
# 0                       Aruba  countries_wb
# 34            Channel Islands  countries_wb
# 47             Cayman Islands  countries_wb
# 65              Faroe Islands  countries_wb
# 66      Micronesia, Fed. Sts.  countries_wb
# 71                  Gibraltar  countries_wb
# 78                  Greenland  countries_wb
# 80                       Guam  countries_wb
# 88                Isle of Man  countries_wb
# 104       St. Kitts and Nevis  countries_wb
# 119  St. Martin (French part)  countries_wb
# 183                  Eswatini  countries_wb
# 187  Turks and Caicos Islands  countries_wb
# 208     Virgin Islands (U.S.)  countries_wb

# %%
# add months with numerical values
 ## check that there is no strange value 

months_str = imm_clean_df['month_str'].unique()
months_str
# Out:
# array(['Feb', 'Jan', 'Mar', 'Apr', 'Jun', 'May', 'Aug', 'Jul', 'Sep',
#        'Dec', 'Nov', 'Oct'], dtype=object)

# %%
# use of Mapping to add integers to month abbreviations

month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}

# Map month abbreviations to integers using the dictionary
imm_clean_df['month_int'] = imm_clean_df['month_str'].map(month_mapping)

imm_clean_df.head(5)
# Out:
#    year quarter month_str              country  immigration_flow  month_int
# 0  2015      Q1       Feb          Afghanistan               125          2
# 1  2015      Q1       Feb              Albania                25          2
# 2  2015      Q1       Feb              Algeria               125          2
# 3  2015      Q1       Feb  Antigua and Barbuda                 5          2
# 4  2015      Q1       Feb            Argentina                15          2

# %%
# organize columns

imm_clean_df = imm_clean_df[['country', 'year', 'month_str', 
                            'month_int','quarter', 'immigration_flow']]
imm_clean_df.head(5)
# Out:
#                country  year month_str  month_int quarter  immigration_flow
# 0          Afghanistan  2015       Feb          2      Q1               125
# 1              Albania  2015       Feb          2      Q1                25
# 2              Algeria  2015       Feb          2      Q1               125
# 3  Antigua and Barbuda  2015       Feb          2      Q1                 5
# 4            Argentina  2015       Feb          2      Q1                15

# %%
imm_new_df = imm_clean_df.reset_index()
imm_new_df.head(5)
# Out:
#    index              country  year month_str  month_int quarter  \
# 0      0          Afghanistan  2015       Feb          2      Q1
# 1      1              Albania  2015       Feb          2      Q1
# 2      2              Algeria  2015       Feb          2      Q1
# 3      3  Antigua and Barbuda  2015       Feb          2      Q1
# 4      4            Argentina  2015       Feb          2      Q1
#
#    immigration_flow
# 0               125
# 1                25
# 2               125
# 3                 5
# 4                15

# %%
# export to CSV

imm_new_df.to_csv('Output/immigrants_by_country_monthly.csv', index=False)

# %%
# groupby country / year to get the total by country

imm_yearly = imm_new_df.groupby(['country','year'])['immigration_flow'].sum()
imm_yearly.to_csv('Output/immigrants_by_country_year.csv')
imm_yearly
# Out:
# country      year
# Afghanistan  2015    2625
#              2016    2655
#              2017    3460
#              2018    3560
#              2019    3890
#                      ...
# Zimbabwe     2020     335
#              2021     505
#              2022     615
#              2023     555
#              2024     505
# Name: immigration_flow, Length: 1855, dtype: int64

# %%
# groupby to get the total by country

imm_bycountry = imm_new_df.groupby(['country'])['immigration_flow'].sum()
imm_bycountry.to_csv('Output/immigrants_by_country.csv')
imm_bycountry
# Out:
# country
# Afghanistan           81305
# Albania                5540
# Algeria               39655
# American Samoa            0
# Andorra                   0
#                       ...
# Viet Nam              41200
# West Bank and Gaza     5920
# Yemen, Rep.            5875
# Zambia                  605
# Zimbabwe               4610
# Name: immigration_flow, Length: 203, dtype: int64

# %% [markdown]
# # (3) Extract macro economic data
# #### from world bank API
# source : https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json

# %%
# the API uses the iso3Code code of the country (example PAK for pakistan, AFG for Afghanistan)
# we need to identify the needed countries from from our immigration_df and retrieve these iso3Code from countries_df

countries_request = pd.merge(imm_new_df, countries_wb_df, left_on='country', right_on='country')
countries_request
# Out:
#        index              country  year month_str  month_int quarter  \
# 0          0          Afghanistan  2015       Feb          2      Q1
# 1          1              Albania  2015       Feb          2      Q1
# 2          2              Algeria  2015       Feb          2      Q1
# 3          3  Antigua and Barbuda  2015       Feb          2      Q1
# 4          4            Argentina  2015       Feb          2      Q1
# ...      ...                  ...   ...       ...        ...     ...
# 19692  19692        Venezuela, RB  2024       Oct         10      Q4
# 19693  19693             Viet Nam  2024       Oct         10      Q4
# 19694  19694          Yemen, Rep.  2024       Oct         10      Q4
# 19695  19695               Zambia  2024       Oct         10      Q4
# 19696  19696             Zimbabwe  2024       Oct         10      Q4
#
#        immigration_flow iso3Code iso2Code                      region  \
# 0                   125      AFG       AF                  South Asia
# 1                    25      ALB       AL       Europe & Central Asia
# 2                   125      DZA       DZ  Middle East & North Africa
# 3                     5      ATG       AG  Latin America & Caribbean
# 4                    15      ARG       AR  Latin America & Caribbean
# ...                 ...      ...      ...                         ...
# 19692               195      VEN       VE  Latin America & Caribbean
# 19693               360      VNM       VN         East Asia & Pacific
# 19694                35      YEM       YE  Middle East & North Africa
# 19695                 0      ZMB       ZM         Sub-Saharan Africa
# 19696                35      ZWE       ZW         Sub-Saharan Africa
#
#         capitalCity longitude  latitude
# 0             Kabul   69.1761   34.5228
# 1            Tirane   19.8172   41.3317
# 2           Algiers   3.05097   36.7397
# 3      Saint John's  -61.8456   17.1175
# 4      Buenos Aires  -58.4173  -34.6118
# ...             ...       ...       ...
# 19692       Caracas  -69.8371   9.08165
# 19693         Hanoi   105.825   21.0069
# 19694        Sana'a   44.2075    15.352
# 19695        Lusaka   28.2937  -15.3982
# 19696        Harare   31.0672  -17.8312
#
# [19697 rows x 13 columns]

# %%
# extrac the needed iso3code in a list to be used to iterate

country_list = countries_request['iso3Code'].unique().sort().tolist()
country_list
# Out:
# ['AFG',
#  'ALB',
#  'DZA',
#  'ATG',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BHS',
#  'BHR',
#  'BGD',
#  'BRB',
#  'BLR',
#  'BEL',
#  'BLZ',
#  'BEN',
#  'BTN',
#  'BOL',
#  'BIH',
#  'BWA',
#  'BRA',
#  'BGR',
#  'BFA',
#  'BDI',
#  'KHM',
#  'CMR',
#  'CAF',
#  'TCD',
#  'CHL',
#  'CHN',
#  'COL',
#  'COM',
#  'COD',
#  'COG',
#  'CRI',
#  'HRV',
#  'CUB',
#  'CYP',
#  'CZE',
#  'DNK',
#  'DJI',
#  'DMA',
#  'DOM',
#  'ECU',
#  'EGY',
#  'SLV',
#  'ERI',
#  'ETH',
#  'FJI',
#  'FIN',
#  'FRA',
#  'GMB',
#  'GEO',
#  'DEU',
#  'GHA',
#  'GRC',
#  'GRD',
#  'GTM',
#  'GIN',
#  'GUY',
#  'HTI',
#  'HND',
#  'HKG',
#  'HUN',
#  'ISL',
#  'IND',
#  'IDN',
#  'IRN',
#  'IRQ',
#  'IRL',
#  'ISR',
#  'ITA',
#  'CIV',
#  'JAM',
#  'JPN',
#  'JOR',
#  'KAZ',
#  'KEN',
#  'KOR',
#  'XKX',
#  'KGZ',
#  'LAO',
#  'LVA',
#  'LBN',
#  'LBR',
#  'LBY',
#  'LTU',
#  'MAC',
#  'MKD',
#  'MDG',
#  'MYS',
#  'MDV',
#  'MLI',
#  'MRT',
#  'MUS',
#  'MEX',
#  'MDA',
#  'MNG',
#  'MNE',
#  'MAR',
#  'MMR',
#  'NAM',
#  'NPL',
#  'NLD',
#  'NZL',
#  'NIC',
#  'NER',
#  'NGA',
#  'NOR',
#  'PAK',
#  'PSE',
#  'PAN',
#  'PRY',
#  'PER',
#  'PHL',
#  'POL',
#  'PRT',
#  'ROU',
#  'RUS',
#  'RWA',
#  'ASM',
#  'SAU',
#  'SEN',
#  'SRB',
#  'SLE',
#  'SGP',
#  'SVK',
#  'SVN',
#  'SOM',
#  'ZAF',
#  'ESP',
#  'LKA',
#  'LCA',
#  'VCT',
#  'CAN',
#  'SDN',
#  'SWE',
#  'CHE',
#  'SYR',
#  'TJK',
#  'TZA',
#  'THA',
#  'TGO',
#  'TTO',
#  'TUN',
#  'TUR',
#  'UGA',
#  'UKR',
#  'GBR',
#  'USA',
#  'URY',
#  'UZB',
#  'VEN',
#  'VNM',
#  'YEM',
#  'ZWE',
#  'AGO',
#  'EST',
#  'GAB',
#  'KWT',
#  'LUX',
#  'MWI',
#  'MOZ',
#  'SLB',
#  'SSD',
#  'TON',
#  'ZMB',
#  'OMN',
#  'AND',
#  'GNB',
#  'PRK',
#  'SUR',
#  'MLT',
#  'BRN',
#  'TKM',
#  'CPV',
#  'PNG',
#  'WSM',
#  'ARE',
#  'QAT',
#  'LSO',
#  'MCO',
#  'SYC',
#  'GNQ',
#  'TLS',
#  'KIR',
#  'SMR',
#  'PLW',
#  'MHL',
#  'BMU',
#  'VGB',
#  'NCL',
#  'MNP',
#  'CUW',
#  'TUV',
#  'LIE',
#  'PRI',
#  'PYF',
#  'NRU',
#  'STP',
#  'VUT',
#  'SXM']

# %%
# import requests

# %%
# this line is just to check that we are connected to the APIT : O TEST before loop

link_pop = f'https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json'
response_pop = requests.get(link_pop).json()

pprint(response_pop)
# Out:
# [{'lastupdated': '2024-12-16',
#   'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'sourceid': '2',
#   'total': 9},
#  [{'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2023',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4660.40545686886},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2022',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4544.46688059647},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2021',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4456.74687641147},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2020',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4363.68533766912},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2019',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4672.66408682198},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2018',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4717.00358853556},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2017',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4742.90075536604},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2016',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4768.73140080218},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2015',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4685.05902729002}]]

# %%
# this cell is used to check our code before to launch the loop 
# TO TEST before loop


link_pop = f'https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json'
response_pop = requests.get(link_pop).json()

# pprint(response_pop)

pop_list = []
for item in response_pop[1]:  # Assuming response_pop[1] is a list of dictionaries
    pop_list.append({
        'iso3Code': item['countryiso3code'],
        'iso2Code': item['country']['id'],
        'Country': item['country']['value'],              
        'year': item['date'],
        'indicator': item['indicator']['value'],
        'value': item['value']
    })

pop_list
# Out:
# [{'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2023',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4660.40545686886},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2022',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4544.46688059647},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2021',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4456.74687641147},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2020',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4363.68533766912},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2019',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4672.66408682198},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2018',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4717.00358853556},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2017',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4742.90075536604},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2016',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4768.73140080218},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2015',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4685.05902729002}]

# %%
# DEFINE THE VARIABLES : INDICATORS, TIME PERIOD



# define 1st and last year f the loop

year_min = 2015
year_max = 2024
years_list = [x for x in range(year_min, year_max +1)]   # COULD BE USED BUT NOT IN THE CURRENT CODE

# %%
# # create the list of indicators
            #  'NY.GDP.PCAP.KD' gdp per capita
            # 'SP.POP.TOTL' total population
            #  SL.UEM.ADVN.ZS : Unemployment with advanced education (% of total labor force with advanced education)
            # SL.UEM.TOTL.NE.ZS : Unemployment, total (% of total labor force) (national estimate)
            # SI.POV.DDAY  Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)

            # Population density (people per sq. km of land area)	EN.POP.DNST
            # Level of water stress: freshwater withdrawal as a proportion of available freshwater resources	ER.H2O.FWST.ZS
            # Market capitalization of listed domestic companies (% of GDP) CM.MKT.LCAP.GD.ZS
            # Rural population (% of total population) SP.RUR.TOTL.ZS
            # S&P Global Equity Indices (annual % change)	CM.MKT.INDX.ZG
            # Voice and Accountability: Number of Sources	VA.NO.SRC




indicators = [
                'NY.GDP.PCAP.KD',
                'SP.POP.TOTL' , 
                'SL.UEM.ADVN.ZS', 
                'SL.UEM.TOTL.NE.ZS', 
                'SI.POV.DDAY',
                'EN.POP.DNST', 
                'ER.H2O.FWST.ZS', 
                'CM.MKT.LCAP.GD.ZS', 
                'SP.RUR.TOTL.ZS', 
                'CM.MKT.INDX.ZG', 
                'VA.NO.SRC' 
                'EG.ELC.ACCS.ZS'  ,
                'EG.CFT.ACCS.ZS'  ,
                'EG.ELC.ACCS.ZS'  ,
                'per_si_allsi.adq_pop_tot'  ,
                'NY.ADJ.NNTY.KD'  ,
                'AG.LND.ARBL.HA.PC'  ,
                'FB.ATM.TOTL.P5'  ,
                'SE.PRM.UNER.ZS'  ,
                'FP.CPI.TOTL'  ,
                'CC.EST'  ,
                'SH.XPD.CHEX.PP.CD'  ,
                'SH.XPD.GHED.PP.CD'  ,

                
                ]

# %%
# lOOP to extract data from API : between 15 and 18 minutes

# this code will loop through all the listed countries and the needed indicators to generate a list

print(f"start code")
print('---------------------------')

macro_eco_data_list = []

# the end point is defined by (i) country (II) indicator (III) year start and year end
        # => we need to create 1 end point of each country / indicator

for i in country_list :

    for j in indicators :

        print(f"--------------------------")
        print(f"country {i} indicator {j}")

        try:

            # define the end point by country (from list I) and indicator (from list J)

            link_pop = f'https://api.worldbank.org/v2/country/{i}/indicator/{j}?date={year_min}:{year_max}&format=json'
            response_pop = requests.get(link_pop).json()

            # loop through the response_pop (list) to extract the value for each year in the serie 

            for item in response_pop[1]:  
                macro_eco_data_list.append({
                    'iso3Code': item['countryiso3code'],
                    'iso2Code': item['country']['id'],
                    'country': item['country']['value'],              
                    'year': item['date'],
                    'indicator': item['indicator']['value'],
                    'value': item['value']
                })
        except:   
            print(f"country {i} indicator {j}....... not found")
# Out:
# start code
# ---------------------------
# --------------------------
# country AFG indicator NY.GDP.PCAP.KD
# --------------------------
# country AFG indicator SP.POP.TOTL
# --------------------------
# country AFG indicator SL.UEM.ADVN.ZS
# --------------------------
# country AFG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AFG indicator SI.POV.DDAY
# --------------------------
# country AFG indicator EN.POP.DNST
# --------------------------
# country AFG indicator ER.H2O.FWST.ZS
# --------------------------
# country AFG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AFG indicator SP.RUR.TOTL.ZS
# --------------------------
# country AFG indicator CM.MKT.INDX.ZG
# --------------------------
# country AFG indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country AFG indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country AFG indicator EG.CFT.ACCS.ZS
# --------------------------
# country AFG indicator EG.ELC.ACCS.ZS
# --------------------------
# country AFG indicator per_si_allsi.adq_pop_tot
# --------------------------
# country AFG indicator NY.ADJ.NNTY.KD
# --------------------------
# country AFG indicator AG.LND.ARBL.HA.PC
# --------------------------
# country AFG indicator FB.ATM.TOTL.P5
# --------------------------
# country AFG indicator SE.PRM.UNER.ZS
# --------------------------
# country AFG indicator FP.CPI.TOTL
# --------------------------
# country AFG indicator CC.EST
# --------------------------
# country AFG indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country AFG indicator SH.XPD.GHED.PP.CD
# --------------------------
# country ALB indicator NY.GDP.PCAP.KD
# --------------------------
# country ALB indicator SP.POP.TOTL
# --------------------------
# country ALB indicator SL.UEM.ADVN.ZS
# --------------------------
# country ALB indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ALB indicator SI.POV.DDAY
# --------------------------
# country ALB indicator EN.POP.DNST
# --------------------------
# country ALB indicator ER.H2O.FWST.ZS
# --------------------------
# country ALB indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ALB indicator SP.RUR.TOTL.ZS
# --------------------------
# country ALB indicator CM.MKT.INDX.ZG
# --------------------------
# country ALB indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country ALB indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country ALB indicator EG.CFT.ACCS.ZS
# --------------------------
# country ALB indicator EG.ELC.ACCS.ZS
# --------------------------
# country ALB indicator per_si_allsi.adq_pop_tot
# --------------------------
# country ALB indicator NY.ADJ.NNTY.KD
# --------------------------
# country ALB indicator AG.LND.ARBL.HA.PC
# --------------------------
# country ALB indicator FB.ATM.TOTL.P5
# --------------------------
# country ALB indicator SE.PRM.UNER.ZS
# --------------------------
# country ALB indicator FP.CPI.TOTL
# --------------------------
# country ALB indicator CC.EST
# --------------------------
# country ALB indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country ALB indicator SH.XPD.GHED.PP.CD
# --------------------------
# country DZA indicator NY.GDP.PCAP.KD
# --------------------------
# country DZA indicator SP.POP.TOTL
# --------------------------
# country DZA indicator SL.UEM.ADVN.ZS
# --------------------------
# country DZA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country DZA indicator SI.POV.DDAY
# --------------------------
# country DZA indicator EN.POP.DNST
# --------------------------
# country DZA indicator ER.H2O.FWST.ZS
# --------------------------
# country DZA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country DZA indicator SP.RUR.TOTL.ZS
# --------------------------
# country DZA indicator CM.MKT.INDX.ZG
# --------------------------
# country DZA indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country DZA indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country DZA indicator EG.CFT.ACCS.ZS
# --------------------------
# country DZA indicator EG.ELC.ACCS.ZS
# --------------------------
# country DZA indicator per_si_allsi.adq_pop_tot
# --------------------------
# country DZA indicator NY.ADJ.NNTY.KD
# --------------------------
# country DZA indicator AG.LND.ARBL.HA.PC
# --------------------------
# country DZA indicator FB.ATM.TOTL.P5
# --------------------------
# country DZA indicator SE.PRM.UNER.ZS
# --------------------------
# country DZA indicator FP.CPI.TOTL
# --------------------------
# country DZA indicator CC.EST
# --------------------------
# country DZA indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country DZA indicator SH.XPD.GHED.PP.CD
# --------------------------
# country ATG indicator NY.GDP.PCAP.KD
# --------------------------
# country ATG indicator SP.POP.TOTL
# --------------------------
# country ATG indicator SL.UEM.ADVN.ZS
# --------------------------
# country ATG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ATG indicator SI.POV.DDAY
# --------------------------
# country ATG indicator EN.POP.DNST
# --------------------------
# country ATG indicator ER.H2O.FWST.ZS
# --------------------------
# country ATG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ATG indicator SP.RUR.TOTL.ZS
# --------------------------
# country ATG indicator CM.MKT.INDX.ZG
# --------------------------
# country ATG indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country ATG indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country ATG indicator EG.CFT.ACCS.ZS
# --------------------------
# country ATG indicator EG.ELC.ACCS.ZS
# --------------------------
# country ATG indicator per_si_allsi.adq_pop_tot
# --------------------------
# country ATG indicator NY.ADJ.NNTY.KD
# --------------------------
# country ATG indicator AG.LND.ARBL.HA.PC
# --------------------------
# country ATG indicator FB.ATM.TOTL.P5
# --------------------------
# country ATG indicator SE.PRM.UNER.ZS
# --------------------------
# country ATG indicator FP.CPI.TOTL
# --------------------------
# country ATG indicator CC.EST
# --------------------------
# country ATG indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country ATG indicator SH.XPD.GHED.PP.CD
# --------------------------
# country ARG indicator NY.GDP.PCAP.KD
# --------------------------
# country ARG indicator SP.POP.TOTL
# --------------------------
# country ARG indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARG indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ARG indicator SI.POV.DDAY
# --------------------------
# country ARG indicator EN.POP.DNST
# --------------------------
# country ARG indicator ER.H2O.FWST.ZS
# --------------------------
# country ARG indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ARG indicator SP.RUR.TOTL.ZS
# --------------------------
# country ARG indicator CM.MKT.INDX.ZG
# --------------------------
# country ARG indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country ARG indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country ARG indicator EG.CFT.ACCS.ZS
# --------------------------
# country ARG indicator EG.ELC.ACCS.ZS
# --------------------------
# country ARG indicator per_si_allsi.adq_pop_tot
# --------------------------
# country ARG indicator NY.ADJ.NNTY.KD
# --------------------------
# country ARG indicator AG.LND.ARBL.HA.PC
# --------------------------
# country ARG indicator FB.ATM.TOTL.P5
# --------------------------
# country ARG indicator SE.PRM.UNER.ZS
# --------------------------
# country ARG indicator FP.CPI.TOTL
# --------------------------
# country ARG indicator CC.EST
# --------------------------
# country ARG indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country ARG indicator SH.XPD.GHED.PP.CD
# --------------------------
# country ARM indicator NY.GDP.PCAP.KD
# --------------------------
# country ARM indicator SP.POP.TOTL
# --------------------------
# country ARM indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country ARM indicator SI.POV.DDAY
# --------------------------
# country ARM indicator EN.POP.DNST
# --------------------------
# country ARM indicator ER.H2O.FWST.ZS
# --------------------------
# country ARM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country ARM indicator SP.RUR.TOTL.ZS
# --------------------------
# country ARM indicator CM.MKT.INDX.ZG
# --------------------------
# country ARM indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country ARM indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country ARM indicator EG.CFT.ACCS.ZS
# --------------------------
# country ARM indicator EG.ELC.ACCS.ZS
# --------------------------
# country ARM indicator per_si_allsi.adq_pop_tot
# --------------------------
# country ARM indicator NY.ADJ.NNTY.KD
# --------------------------
# country ARM indicator AG.LND.ARBL.HA.PC
# --------------------------
# country ARM indicator FB.ATM.TOTL.P5
# --------------------------
# country ARM indicator SE.PRM.UNER.ZS
# --------------------------
# country ARM indicator FP.CPI.TOTL
# --------------------------
# country ARM indicator CC.EST
# --------------------------
# country ARM indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country ARM indicator SH.XPD.GHED.PP.CD
# --------------------------
# country AUS indicator NY.GDP.PCAP.KD
# --------------------------
# country AUS indicator SP.POP.TOTL
# --------------------------
# country AUS indicator SL.UEM.ADVN.ZS
# --------------------------
# country AUS indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AUS indicator SI.POV.DDAY
# --------------------------
# country AUS indicator EN.POP.DNST
# --------------------------
# country AUS indicator ER.H2O.FWST.ZS
# --------------------------
# country AUS indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AUS indicator SP.RUR.TOTL.ZS
# --------------------------
# country AUS indicator CM.MKT.INDX.ZG
# --------------------------
# country AUS indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country AUS indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country AUS indicator EG.CFT.ACCS.ZS
# --------------------------
# country AUS indicator EG.ELC.ACCS.ZS
# --------------------------
# country AUS indicator per_si_allsi.adq_pop_tot
# --------------------------
# country AUS indicator NY.ADJ.NNTY.KD
# --------------------------
# country AUS indicator AG.LND.ARBL.HA.PC
# --------------------------
# country AUS indicator FB.ATM.TOTL.P5
# --------------------------
# country AUS indicator SE.PRM.UNER.ZS
# --------------------------
# country AUS indicator FP.CPI.TOTL
# --------------------------
# country AUS indicator CC.EST
# --------------------------
# country AUS indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country AUS indicator SH.XPD.GHED.PP.CD
# --------------------------
# country AUT indicator NY.GDP.PCAP.KD
# --------------------------
# country AUT indicator SP.POP.TOTL
# --------------------------
# country AUT indicator SL.UEM.ADVN.ZS
# --------------------------
# country AUT indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AUT indicator SI.POV.DDAY
# --------------------------
# country AUT indicator EN.POP.DNST
# --------------------------
# country AUT indicator ER.H2O.FWST.ZS
# --------------------------
# country AUT indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AUT indicator SP.RUR.TOTL.ZS
# --------------------------
# country AUT indicator CM.MKT.INDX.ZG
# --------------------------
# country AUT indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country AUT indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country AUT indicator EG.CFT.ACCS.ZS
# --------------------------
# country AUT indicator EG.ELC.ACCS.ZS
# --------------------------
# country AUT indicator per_si_allsi.adq_pop_tot
# --------------------------
# country AUT indicator NY.ADJ.NNTY.KD
# --------------------------
# country AUT indicator AG.LND.ARBL.HA.PC
# --------------------------
# country AUT indicator FB.ATM.TOTL.P5
# --------------------------
# country AUT indicator SE.PRM.UNER.ZS
# --------------------------
# country AUT indicator FP.CPI.TOTL
# --------------------------
# country AUT indicator CC.EST
# --------------------------
# country AUT indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country AUT indicator SH.XPD.GHED.PP.CD
# --------------------------
# country AZE indicator NY.GDP.PCAP.KD
# --------------------------
# country AZE indicator SP.POP.TOTL
# --------------------------
# country AZE indicator SL.UEM.ADVN.ZS
# --------------------------
# country AZE indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country AZE indicator SI.POV.DDAY
# --------------------------
# country AZE indicator EN.POP.DNST
# --------------------------
# country AZE indicator ER.H2O.FWST.ZS
# --------------------------
# country AZE indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country AZE indicator SP.RUR.TOTL.ZS
# --------------------------
# country AZE indicator CM.MKT.INDX.ZG
# --------------------------
# country AZE indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country AZE indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country AZE indicator EG.CFT.ACCS.ZS
# --------------------------
# country AZE indicator EG.ELC.ACCS.ZS
# --------------------------
# country AZE indicator per_si_allsi.adq_pop_tot
# --------------------------
# country AZE indicator NY.ADJ.NNTY.KD
# --------------------------
# country AZE indicator AG.LND.ARBL.HA.PC
# --------------------------
# country AZE indicator FB.ATM.TOTL.P5
# --------------------------
# country AZE indicator SE.PRM.UNER.ZS
# --------------------------
# country AZE indicator FP.CPI.TOTL
# --------------------------
# country AZE indicator CC.EST
# --------------------------
# country AZE indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country AZE indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BHS indicator NY.GDP.PCAP.KD
# --------------------------
# country BHS indicator SP.POP.TOTL
# --------------------------
# country BHS indicator SL.UEM.ADVN.ZS
# --------------------------
# country BHS indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BHS indicator SI.POV.DDAY
# --------------------------
# country BHS indicator EN.POP.DNST
# --------------------------
# country BHS indicator ER.H2O.FWST.ZS
# --------------------------
# country BHS indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BHS indicator SP.RUR.TOTL.ZS
# --------------------------
# country BHS indicator CM.MKT.INDX.ZG
# --------------------------
# country BHS indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BHS indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BHS indicator EG.CFT.ACCS.ZS
# --------------------------
# country BHS indicator EG.ELC.ACCS.ZS
# --------------------------
# country BHS indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BHS indicator NY.ADJ.NNTY.KD
# --------------------------
# country BHS indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BHS indicator FB.ATM.TOTL.P5
# --------------------------
# country BHS indicator SE.PRM.UNER.ZS
# --------------------------
# country BHS indicator FP.CPI.TOTL
# --------------------------
# country BHS indicator CC.EST
# --------------------------
# country BHS indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BHS indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BHR indicator NY.GDP.PCAP.KD
# --------------------------
# country BHR indicator SP.POP.TOTL
# --------------------------
# country BHR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BHR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BHR indicator SI.POV.DDAY
# --------------------------
# country BHR indicator EN.POP.DNST
# --------------------------
# country BHR indicator ER.H2O.FWST.ZS
# --------------------------
# country BHR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BHR indicator SP.RUR.TOTL.ZS
# --------------------------
# country BHR indicator CM.MKT.INDX.ZG
# --------------------------
# country BHR indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BHR indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BHR indicator EG.CFT.ACCS.ZS
# --------------------------
# country BHR indicator EG.ELC.ACCS.ZS
# --------------------------
# country BHR indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BHR indicator NY.ADJ.NNTY.KD
# --------------------------
# country BHR indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BHR indicator FB.ATM.TOTL.P5
# --------------------------
# country BHR indicator SE.PRM.UNER.ZS
# --------------------------
# country BHR indicator FP.CPI.TOTL
# --------------------------
# country BHR indicator CC.EST
# --------------------------
# country BHR indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BHR indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BGD indicator NY.GDP.PCAP.KD
# --------------------------
# country BGD indicator SP.POP.TOTL
# --------------------------
# country BGD indicator SL.UEM.ADVN.ZS
# --------------------------
# country BGD indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BGD indicator SI.POV.DDAY
# --------------------------
# country BGD indicator EN.POP.DNST
# --------------------------
# country BGD indicator ER.H2O.FWST.ZS
# --------------------------
# country BGD indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BGD indicator SP.RUR.TOTL.ZS
# --------------------------
# country BGD indicator CM.MKT.INDX.ZG
# --------------------------
# country BGD indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BGD indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BGD indicator EG.CFT.ACCS.ZS
# --------------------------
# country BGD indicator EG.ELC.ACCS.ZS
# --------------------------
# country BGD indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BGD indicator NY.ADJ.NNTY.KD
# --------------------------
# country BGD indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BGD indicator FB.ATM.TOTL.P5
# --------------------------
# country BGD indicator SE.PRM.UNER.ZS
# --------------------------
# country BGD indicator FP.CPI.TOTL
# --------------------------
# country BGD indicator CC.EST
# --------------------------
# country BGD indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BGD indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BRB indicator NY.GDP.PCAP.KD
# --------------------------
# country BRB indicator SP.POP.TOTL
# --------------------------
# country BRB indicator SL.UEM.ADVN.ZS
# --------------------------
# country BRB indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BRB indicator SI.POV.DDAY
# --------------------------
# country BRB indicator EN.POP.DNST
# --------------------------
# country BRB indicator ER.H2O.FWST.ZS
# --------------------------
# country BRB indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BRB indicator SP.RUR.TOTL.ZS
# --------------------------
# country BRB indicator CM.MKT.INDX.ZG
# --------------------------
# country BRB indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BRB indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BRB indicator EG.CFT.ACCS.ZS
# --------------------------
# country BRB indicator EG.ELC.ACCS.ZS
# --------------------------
# country BRB indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BRB indicator NY.ADJ.NNTY.KD
# --------------------------
# country BRB indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BRB indicator FB.ATM.TOTL.P5
# --------------------------
# country BRB indicator SE.PRM.UNER.ZS
# --------------------------
# country BRB indicator FP.CPI.TOTL
# --------------------------
# country BRB indicator CC.EST
# --------------------------
# country BRB indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BRB indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BLR indicator NY.GDP.PCAP.KD
# --------------------------
# country BLR indicator SP.POP.TOTL
# --------------------------
# country BLR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BLR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BLR indicator SI.POV.DDAY
# --------------------------
# country BLR indicator EN.POP.DNST
# --------------------------
# country BLR indicator ER.H2O.FWST.ZS
# --------------------------
# country BLR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BLR indicator SP.RUR.TOTL.ZS
# --------------------------
# country BLR indicator CM.MKT.INDX.ZG
# --------------------------
# country BLR indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BLR indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BLR indicator EG.CFT.ACCS.ZS
# --------------------------
# country BLR indicator EG.ELC.ACCS.ZS
# --------------------------
# country BLR indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BLR indicator NY.ADJ.NNTY.KD
# --------------------------
# country BLR indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BLR indicator FB.ATM.TOTL.P5
# --------------------------
# country BLR indicator SE.PRM.UNER.ZS
# --------------------------
# country BLR indicator FP.CPI.TOTL
# --------------------------
# country BLR indicator CC.EST
# --------------------------
# country BLR indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BLR indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BEL indicator NY.GDP.PCAP.KD
# --------------------------
# country BEL indicator SP.POP.TOTL
# --------------------------
# country BEL indicator SL.UEM.ADVN.ZS
# --------------------------
# country BEL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BEL indicator SI.POV.DDAY
# --------------------------
# country BEL indicator EN.POP.DNST
# --------------------------
# country BEL indicator ER.H2O.FWST.ZS
# --------------------------
# country BEL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BEL indicator SP.RUR.TOTL.ZS
# --------------------------
# country BEL indicator CM.MKT.INDX.ZG
# --------------------------
# country BEL indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BEL indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BEL indicator EG.CFT.ACCS.ZS
# --------------------------
# country BEL indicator EG.ELC.ACCS.ZS
# --------------------------
# country BEL indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BEL indicator NY.ADJ.NNTY.KD
# --------------------------
# country BEL indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BEL indicator FB.ATM.TOTL.P5
# --------------------------
# country BEL indicator SE.PRM.UNER.ZS
# --------------------------
# country BEL indicator FP.CPI.TOTL
# --------------------------
# country BEL indicator CC.EST
# --------------------------
# country BEL indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BEL indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BLZ indicator NY.GDP.PCAP.KD
# --------------------------
# country BLZ indicator SP.POP.TOTL
# --------------------------
# country BLZ indicator SL.UEM.ADVN.ZS
# --------------------------
# country BLZ indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BLZ indicator SI.POV.DDAY
# --------------------------
# country BLZ indicator EN.POP.DNST
# --------------------------
# country BLZ indicator ER.H2O.FWST.ZS
# --------------------------
# country BLZ indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BLZ indicator SP.RUR.TOTL.ZS
# --------------------------
# country BLZ indicator CM.MKT.INDX.ZG
# --------------------------
# country BLZ indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BLZ indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BLZ indicator EG.CFT.ACCS.ZS
# --------------------------
# country BLZ indicator EG.ELC.ACCS.ZS
# --------------------------
# country BLZ indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BLZ indicator NY.ADJ.NNTY.KD
# --------------------------
# country BLZ indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BLZ indicator FB.ATM.TOTL.P5
# --------------------------
# country BLZ indicator SE.PRM.UNER.ZS
# --------------------------
# country BLZ indicator FP.CPI.TOTL
# --------------------------
# country BLZ indicator CC.EST
# --------------------------
# country BLZ indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BLZ indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BEN indicator NY.GDP.PCAP.KD
# --------------------------
# country BEN indicator SP.POP.TOTL
# --------------------------
# country BEN indicator SL.UEM.ADVN.ZS
# --------------------------
# country BEN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BEN indicator SI.POV.DDAY
# --------------------------
# country BEN indicator EN.POP.DNST
# --------------------------
# country BEN indicator ER.H2O.FWST.ZS
# --------------------------
# country BEN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BEN indicator SP.RUR.TOTL.ZS
# --------------------------
# country BEN indicator CM.MKT.INDX.ZG
# --------------------------
# country BEN indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BEN indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BEN indicator EG.CFT.ACCS.ZS
# --------------------------
# country BEN indicator EG.ELC.ACCS.ZS
# --------------------------
# country BEN indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BEN indicator NY.ADJ.NNTY.KD
# --------------------------
# country BEN indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BEN indicator FB.ATM.TOTL.P5
# --------------------------
# country BEN indicator SE.PRM.UNER.ZS
# --------------------------
# country BEN indicator FP.CPI.TOTL
# --------------------------
# country BEN indicator CC.EST
# --------------------------
# country BEN indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BEN indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BTN indicator NY.GDP.PCAP.KD
# --------------------------
# country BTN indicator SP.POP.TOTL
# --------------------------
# country BTN indicator SL.UEM.ADVN.ZS
# --------------------------
# country BTN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BTN indicator SI.POV.DDAY
# --------------------------
# country BTN indicator EN.POP.DNST
# --------------------------
# country BTN indicator ER.H2O.FWST.ZS
# --------------------------
# country BTN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BTN indicator SP.RUR.TOTL.ZS
# --------------------------
# country BTN indicator CM.MKT.INDX.ZG
# --------------------------
# country BTN indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BTN indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BTN indicator EG.CFT.ACCS.ZS
# --------------------------
# country BTN indicator EG.ELC.ACCS.ZS
# --------------------------
# country BTN indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BTN indicator NY.ADJ.NNTY.KD
# --------------------------
# country BTN indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BTN indicator FB.ATM.TOTL.P5
# --------------------------
# country BTN indicator SE.PRM.UNER.ZS
# --------------------------
# country BTN indicator FP.CPI.TOTL
# --------------------------
# country BTN indicator CC.EST
# --------------------------
# country BTN indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BTN indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BOL indicator NY.GDP.PCAP.KD
# --------------------------
# country BOL indicator SP.POP.TOTL
# --------------------------
# country BOL indicator SL.UEM.ADVN.ZS
# --------------------------
# country BOL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BOL indicator SI.POV.DDAY
# --------------------------
# country BOL indicator EN.POP.DNST
# --------------------------
# country BOL indicator ER.H2O.FWST.ZS
# --------------------------
# country BOL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BOL indicator SP.RUR.TOTL.ZS
# --------------------------
# country BOL indicator CM.MKT.INDX.ZG
# --------------------------
# country BOL indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BOL indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BOL indicator EG.CFT.ACCS.ZS
# --------------------------
# country BOL indicator EG.ELC.ACCS.ZS
# --------------------------
# country BOL indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BOL indicator NY.ADJ.NNTY.KD
# --------------------------
# country BOL indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BOL indicator FB.ATM.TOTL.P5
# --------------------------
# country BOL indicator SE.PRM.UNER.ZS
# --------------------------
# country BOL indicator FP.CPI.TOTL
# --------------------------
# country BOL indicator CC.EST
# --------------------------
# country BOL indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BOL indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BIH indicator NY.GDP.PCAP.KD
# --------------------------
# country BIH indicator SP.POP.TOTL
# --------------------------
# country BIH indicator SL.UEM.ADVN.ZS
# --------------------------
# country BIH indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BIH indicator SI.POV.DDAY
# --------------------------
# country BIH indicator EN.POP.DNST
# --------------------------
# country BIH indicator ER.H2O.FWST.ZS
# --------------------------
# country BIH indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BIH indicator SP.RUR.TOTL.ZS
# --------------------------
# country BIH indicator CM.MKT.INDX.ZG
# --------------------------
# country BIH indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BIH indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BIH indicator EG.CFT.ACCS.ZS
# --------------------------
# country BIH indicator EG.ELC.ACCS.ZS
# --------------------------
# country BIH indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BIH indicator NY.ADJ.NNTY.KD
# --------------------------
# country BIH indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BIH indicator FB.ATM.TOTL.P5
# --------------------------
# country BIH indicator SE.PRM.UNER.ZS
# --------------------------
# country BIH indicator FP.CPI.TOTL
# --------------------------
# country BIH indicator CC.EST
# --------------------------
# country BIH indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BIH indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BWA indicator NY.GDP.PCAP.KD
# --------------------------
# country BWA indicator SP.POP.TOTL
# --------------------------
# country BWA indicator SL.UEM.ADVN.ZS
# --------------------------
# country BWA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BWA indicator SI.POV.DDAY
# --------------------------
# country BWA indicator EN.POP.DNST
# --------------------------
# country BWA indicator ER.H2O.FWST.ZS
# --------------------------
# country BWA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BWA indicator SP.RUR.TOTL.ZS
# --------------------------
# country BWA indicator CM.MKT.INDX.ZG
# --------------------------
# country BWA indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BWA indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BWA indicator EG.CFT.ACCS.ZS
# --------------------------
# country BWA indicator EG.ELC.ACCS.ZS
# --------------------------
# country BWA indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BWA indicator NY.ADJ.NNTY.KD
# --------------------------
# country BWA indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BWA indicator FB.ATM.TOTL.P5
# --------------------------
# country BWA indicator SE.PRM.UNER.ZS
# --------------------------
# country BWA indicator FP.CPI.TOTL
# --------------------------
# country BWA indicator CC.EST
# --------------------------
# country BWA indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BWA indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BRA indicator NY.GDP.PCAP.KD
# --------------------------
# country BRA indicator SP.POP.TOTL
# --------------------------
# country BRA indicator SL.UEM.ADVN.ZS
# --------------------------
# country BRA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BRA indicator SI.POV.DDAY
# --------------------------
# country BRA indicator EN.POP.DNST
# --------------------------
# country BRA indicator ER.H2O.FWST.ZS
# --------------------------
# country BRA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BRA indicator SP.RUR.TOTL.ZS
# --------------------------
# country BRA indicator CM.MKT.INDX.ZG
# --------------------------
# country BRA indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BRA indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BRA indicator EG.CFT.ACCS.ZS
# --------------------------
# country BRA indicator EG.ELC.ACCS.ZS
# --------------------------
# country BRA indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BRA indicator NY.ADJ.NNTY.KD
# --------------------------
# country BRA indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BRA indicator FB.ATM.TOTL.P5
# --------------------------
# country BRA indicator SE.PRM.UNER.ZS
# --------------------------
# country BRA indicator FP.CPI.TOTL
# --------------------------
# country BRA indicator CC.EST
# --------------------------
# country BRA indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BRA indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BGR indicator NY.GDP.PCAP.KD
# --------------------------
# country BGR indicator SP.POP.TOTL
# --------------------------
# country BGR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BGR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BGR indicator SI.POV.DDAY
# --------------------------
# country BGR indicator EN.POP.DNST
# --------------------------
# country BGR indicator ER.H2O.FWST.ZS
# --------------------------
# country BGR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BGR indicator SP.RUR.TOTL.ZS
# --------------------------
# country BGR indicator CM.MKT.INDX.ZG
# --------------------------
# country BGR indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BGR indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BGR indicator EG.CFT.ACCS.ZS
# --------------------------
# country BGR indicator EG.ELC.ACCS.ZS
# --------------------------
# country BGR indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BGR indicator NY.ADJ.NNTY.KD
# --------------------------
# country BGR indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BGR indicator FB.ATM.TOTL.P5
# --------------------------
# country BGR indicator SE.PRM.UNER.ZS
# --------------------------
# country BGR indicator FP.CPI.TOTL
# --------------------------
# country BGR indicator CC.EST
# --------------------------
# country BGR indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BGR indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BFA indicator NY.GDP.PCAP.KD
# --------------------------
# country BFA indicator SP.POP.TOTL
# --------------------------
# country BFA indicator SL.UEM.ADVN.ZS
# --------------------------
# country BFA indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BFA indicator SI.POV.DDAY
# --------------------------
# country BFA indicator EN.POP.DNST
# --------------------------
# country BFA indicator ER.H2O.FWST.ZS
# --------------------------
# country BFA indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BFA indicator SP.RUR.TOTL.ZS
# --------------------------
# country BFA indicator CM.MKT.INDX.ZG
# --------------------------
# country BFA indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BFA indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BFA indicator EG.CFT.ACCS.ZS
# --------------------------
# country BFA indicator EG.ELC.ACCS.ZS
# --------------------------
# country BFA indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BFA indicator NY.ADJ.NNTY.KD
# --------------------------
# country BFA indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BFA indicator FB.ATM.TOTL.P5
# --------------------------
# country BFA indicator SE.PRM.UNER.ZS
# --------------------------
# country BFA indicator FP.CPI.TOTL
# --------------------------
# country BFA indicator CC.EST
# --------------------------
# country BFA indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BFA indicator SH.XPD.GHED.PP.CD
# --------------------------
# country BDI indicator NY.GDP.PCAP.KD
# --------------------------
# country BDI indicator SP.POP.TOTL
# --------------------------
# country BDI indicator SL.UEM.ADVN.ZS
# --------------------------
# country BDI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country BDI indicator SI.POV.DDAY
# --------------------------
# country BDI indicator EN.POP.DNST
# --------------------------
# country BDI indicator ER.H2O.FWST.ZS
# --------------------------
# country BDI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country BDI indicator SP.RUR.TOTL.ZS
# --------------------------
# country BDI indicator CM.MKT.INDX.ZG
# --------------------------
# country BDI indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country BDI indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country BDI indicator EG.CFT.ACCS.ZS
# --------------------------
# country BDI indicator EG.ELC.ACCS.ZS
# --------------------------
# country BDI indicator per_si_allsi.adq_pop_tot
# --------------------------
# country BDI indicator NY.ADJ.NNTY.KD
# --------------------------
# country BDI indicator AG.LND.ARBL.HA.PC
# --------------------------
# country BDI indicator FB.ATM.TOTL.P5
# --------------------------
# country BDI indicator SE.PRM.UNER.ZS
# --------------------------
# country BDI indicator FP.CPI.TOTL
# --------------------------
# country BDI indicator CC.EST
# --------------------------
# country BDI indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country BDI indicator SH.XPD.GHED.PP.CD
# --------------------------
# country KHM indicator NY.GDP.PCAP.KD
# --------------------------
# country KHM indicator SP.POP.TOTL
# --------------------------
# country KHM indicator SL.UEM.ADVN.ZS
# --------------------------
# country KHM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country KHM indicator SI.POV.DDAY
# --------------------------
# country KHM indicator EN.POP.DNST
# --------------------------
# country KHM indicator ER.H2O.FWST.ZS
# --------------------------
# country KHM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country KHM indicator SP.RUR.TOTL.ZS
# --------------------------
# country KHM indicator CM.MKT.INDX.ZG
# --------------------------
# country KHM indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country KHM indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country KHM indicator EG.CFT.ACCS.ZS
# --------------------------
# country KHM indicator EG.ELC.ACCS.ZS
# --------------------------
# country KHM indicator per_si_allsi.adq_pop_tot
# --------------------------
# country KHM indicator NY.ADJ.NNTY.KD
# --------------------------
# country KHM indicator AG.LND.ARBL.HA.PC
# --------------------------
# country KHM indicator FB.ATM.TOTL.P5
# --------------------------
# country KHM indicator SE.PRM.UNER.ZS
# --------------------------
# country KHM indicator FP.CPI.TOTL
# --------------------------
# country KHM indicator CC.EST
# --------------------------
# country KHM indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country KHM indicator SH.XPD.GHED.PP.CD
# --------------------------
# country CMR indicator NY.GDP.PCAP.KD
# --------------------------
# country CMR indicator SP.POP.TOTL
# --------------------------
# country CMR indicator SL.UEM.ADVN.ZS
# --------------------------
# country CMR indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CMR indicator SI.POV.DDAY
# --------------------------
# country CMR indicator EN.POP.DNST
# --------------------------
# country CMR indicator ER.H2O.FWST.ZS
# --------------------------
# country CMR indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CMR indicator SP.RUR.TOTL.ZS
# --------------------------
# country CMR indicator CM.MKT.INDX.ZG
# --------------------------
# country CMR indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country CMR indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country CMR indicator EG.CFT.ACCS.ZS
# --------------------------
# country CMR indicator EG.ELC.ACCS.ZS
# --------------------------
# country CMR indicator per_si_allsi.adq_pop_tot
# --------------------------
# country CMR indicator NY.ADJ.NNTY.KD
# --------------------------
# country CMR indicator AG.LND.ARBL.HA.PC
# --------------------------
# country CMR indicator FB.ATM.TOTL.P5
# --------------------------
# country CMR indicator SE.PRM.UNER.ZS
# --------------------------
# country CMR indicator FP.CPI.TOTL
# --------------------------
# country CMR indicator CC.EST
# --------------------------
# country CMR indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country CMR indicator SH.XPD.GHED.PP.CD
# --------------------------
# country CAF indicator NY.GDP.PCAP.KD
# --------------------------
# country CAF indicator SP.POP.TOTL
# --------------------------
# country CAF indicator SL.UEM.ADVN.ZS
# --------------------------
# country CAF indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CAF indicator SI.POV.DDAY
# --------------------------
# country CAF indicator EN.POP.DNST
# --------------------------
# country CAF indicator ER.H2O.FWST.ZS
# --------------------------
# country CAF indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CAF indicator SP.RUR.TOTL.ZS
# --------------------------
# country CAF indicator CM.MKT.INDX.ZG
# --------------------------
# country CAF indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country CAF indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country CAF indicator EG.CFT.ACCS.ZS
# --------------------------
# country CAF indicator EG.ELC.ACCS.ZS
# --------------------------
# country CAF indicator per_si_allsi.adq_pop_tot
# --------------------------
# country CAF indicator NY.ADJ.NNTY.KD
# --------------------------
# country CAF indicator AG.LND.ARBL.HA.PC
# --------------------------
# country CAF indicator FB.ATM.TOTL.P5
# --------------------------
# country CAF indicator SE.PRM.UNER.ZS
# --------------------------
# country CAF indicator FP.CPI.TOTL
# --------------------------
# country CAF indicator CC.EST
# --------------------------
# country CAF indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country CAF indicator SH.XPD.GHED.PP.CD
# --------------------------
# country TCD indicator NY.GDP.PCAP.KD
# --------------------------
# country TCD indicator SP.POP.TOTL
# --------------------------
# country TCD indicator SL.UEM.ADVN.ZS
# --------------------------
# country TCD indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country TCD indicator SI.POV.DDAY
# --------------------------
# country TCD indicator EN.POP.DNST
# --------------------------
# country TCD indicator ER.H2O.FWST.ZS
# --------------------------
# country TCD indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country TCD indicator SP.RUR.TOTL.ZS
# --------------------------
# country TCD indicator CM.MKT.INDX.ZG
# --------------------------
# country TCD indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country TCD indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country TCD indicator EG.CFT.ACCS.ZS
# --------------------------
# country TCD indicator EG.ELC.ACCS.ZS
# --------------------------
# country TCD indicator per_si_allsi.adq_pop_tot
# --------------------------
# country TCD indicator NY.ADJ.NNTY.KD
# --------------------------
# country TCD indicator AG.LND.ARBL.HA.PC
# --------------------------
# country TCD indicator FB.ATM.TOTL.P5
# --------------------------
# country TCD indicator SE.PRM.UNER.ZS
# --------------------------
# country TCD indicator FP.CPI.TOTL
# --------------------------
# country TCD indicator CC.EST
# --------------------------
# country TCD indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country TCD indicator SH.XPD.GHED.PP.CD
# --------------------------
# country CHL indicator NY.GDP.PCAP.KD
# --------------------------
# country CHL indicator SP.POP.TOTL
# --------------------------
# country CHL indicator SL.UEM.ADVN.ZS
# --------------------------
# country CHL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CHL indicator SI.POV.DDAY
# --------------------------
# country CHL indicator EN.POP.DNST
# --------------------------
# country CHL indicator ER.H2O.FWST.ZS
# --------------------------
# country CHL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CHL indicator SP.RUR.TOTL.ZS
# --------------------------
# country CHL indicator CM.MKT.INDX.ZG
# --------------------------
# country CHL indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country CHL indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country CHL indicator EG.CFT.ACCS.ZS
# --------------------------
# country CHL indicator EG.ELC.ACCS.ZS
# --------------------------
# country CHL indicator per_si_allsi.adq_pop_tot
# --------------------------
# country CHL indicator NY.ADJ.NNTY.KD
# --------------------------
# country CHL indicator AG.LND.ARBL.HA.PC
# --------------------------
# country CHL indicator FB.ATM.TOTL.P5
# --------------------------
# country CHL indicator SE.PRM.UNER.ZS
# --------------------------
# country CHL indicator FP.CPI.TOTL
# --------------------------
# country CHL indicator CC.EST
# --------------------------
# country CHL indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country CHL indicator SH.XPD.GHED.PP.CD
# --------------------------
# country CHN indicator NY.GDP.PCAP.KD
# --------------------------
# country CHN indicator SP.POP.TOTL
# --------------------------
# country CHN indicator SL.UEM.ADVN.ZS
# --------------------------
# country CHN indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CHN indicator SI.POV.DDAY
# --------------------------
# country CHN indicator EN.POP.DNST
# --------------------------
# country CHN indicator ER.H2O.FWST.ZS
# --------------------------
# country CHN indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CHN indicator SP.RUR.TOTL.ZS
# --------------------------
# country CHN indicator CM.MKT.INDX.ZG
# --------------------------
# country CHN indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country CHN indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country CHN indicator EG.CFT.ACCS.ZS
# --------------------------
# country CHN indicator EG.ELC.ACCS.ZS
# --------------------------
# country CHN indicator per_si_allsi.adq_pop_tot
# --------------------------
# country CHN indicator NY.ADJ.NNTY.KD
# --------------------------
# country CHN indicator AG.LND.ARBL.HA.PC
# --------------------------
# country CHN indicator FB.ATM.TOTL.P5
# --------------------------
# country CHN indicator SE.PRM.UNER.ZS
# --------------------------
# country CHN indicator FP.CPI.TOTL
# --------------------------
# country CHN indicator CC.EST
# --------------------------
# country CHN indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country CHN indicator SH.XPD.GHED.PP.CD
# --------------------------
# country COL indicator NY.GDP.PCAP.KD
# --------------------------
# country COL indicator SP.POP.TOTL
# --------------------------
# country COL indicator SL.UEM.ADVN.ZS
# --------------------------
# country COL indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country COL indicator SI.POV.DDAY
# --------------------------
# country COL indicator EN.POP.DNST
# --------------------------
# country COL indicator ER.H2O.FWST.ZS
# --------------------------
# country COL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country COL indicator SP.RUR.TOTL.ZS
# --------------------------
# country COL indicator CM.MKT.INDX.ZG
# --------------------------
# country COL indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country COL indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country COL indicator EG.CFT.ACCS.ZS
# --------------------------
# country COL indicator EG.ELC.ACCS.ZS
# --------------------------
# country COL indicator per_si_allsi.adq_pop_tot
# --------------------------
# country COL indicator NY.ADJ.NNTY.KD
# --------------------------
# country COL indicator AG.LND.ARBL.HA.PC
# --------------------------
# country COL indicator FB.ATM.TOTL.P5
# --------------------------
# country COL indicator SE.PRM.UNER.ZS
# --------------------------
# country COL indicator FP.CPI.TOTL
# --------------------------
# country COL indicator CC.EST
# --------------------------
# country COL indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country COL indicator SH.XPD.GHED.PP.CD
# --------------------------
# country COM indicator NY.GDP.PCAP.KD
# --------------------------
# country COM indicator SP.POP.TOTL
# --------------------------
# country COM indicator SL.UEM.ADVN.ZS
# --------------------------
# country COM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country COM indicator SI.POV.DDAY
# --------------------------
# country COM indicator EN.POP.DNST
# --------------------------
# ...
# country NCL indicator EN.POP.DNST
# --------------------------
# country NCL indicator ER.H2O.FWST.ZS
# --------------------------
# country NCL indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country NCL indicator SP.RUR.TOTL.ZS
# --------------------------
# country NCL indicator CM.MKT.INDX.ZG
# --------------------------
# country NCL indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country NCL indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country NCL indicator EG.CFT.ACCS.ZS
# --------------------------
# country NCL indicator EG.ELC.ACCS.ZS
# --------------------------
# country NCL indicator per_si_allsi.adq_pop_tot
# --------------------------
# country NCL indicator NY.ADJ.NNTY.KD
# --------------------------
# country NCL indicator AG.LND.ARBL.HA.PC
# --------------------------
# country NCL indicator FB.ATM.TOTL.P5
# --------------------------
# country NCL indicator SE.PRM.UNER.ZS
# --------------------------
# country NCL indicator FP.CPI.TOTL
# --------------------------
# country NCL indicator CC.EST
# --------------------------
# country NCL indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country NCL indicator SH.XPD.GHED.PP.CD
# --------------------------
# country MNP indicator NY.GDP.PCAP.KD
# --------------------------
# country MNP indicator SP.POP.TOTL
# --------------------------
# country MNP indicator SL.UEM.ADVN.ZS
# --------------------------
# country MNP indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country MNP indicator SI.POV.DDAY
# --------------------------
# country MNP indicator EN.POP.DNST
# --------------------------
# country MNP indicator ER.H2O.FWST.ZS
# --------------------------
# country MNP indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country MNP indicator SP.RUR.TOTL.ZS
# --------------------------
# country MNP indicator CM.MKT.INDX.ZG
# --------------------------
# country MNP indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country MNP indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country MNP indicator EG.CFT.ACCS.ZS
# --------------------------
# country MNP indicator EG.ELC.ACCS.ZS
# --------------------------
# country MNP indicator per_si_allsi.adq_pop_tot
# --------------------------
# country MNP indicator NY.ADJ.NNTY.KD
# --------------------------
# country MNP indicator AG.LND.ARBL.HA.PC
# --------------------------
# country MNP indicator FB.ATM.TOTL.P5
# --------------------------
# country MNP indicator SE.PRM.UNER.ZS
# --------------------------
# country MNP indicator FP.CPI.TOTL
# --------------------------
# country MNP indicator CC.EST
# --------------------------
# country MNP indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country MNP indicator SH.XPD.GHED.PP.CD
# --------------------------
# country CUW indicator NY.GDP.PCAP.KD
# --------------------------
# country CUW indicator SP.POP.TOTL
# --------------------------
# country CUW indicator SL.UEM.ADVN.ZS
# --------------------------
# country CUW indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country CUW indicator SI.POV.DDAY
# --------------------------
# country CUW indicator EN.POP.DNST
# --------------------------
# country CUW indicator ER.H2O.FWST.ZS
# --------------------------
# country CUW indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country CUW indicator SP.RUR.TOTL.ZS
# --------------------------
# country CUW indicator CM.MKT.INDX.ZG
# --------------------------
# country CUW indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country CUW indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country CUW indicator EG.CFT.ACCS.ZS
# --------------------------
# country CUW indicator EG.ELC.ACCS.ZS
# --------------------------
# country CUW indicator per_si_allsi.adq_pop_tot
# --------------------------
# country CUW indicator NY.ADJ.NNTY.KD
# --------------------------
# country CUW indicator AG.LND.ARBL.HA.PC
# --------------------------
# country CUW indicator FB.ATM.TOTL.P5
# --------------------------
# country CUW indicator SE.PRM.UNER.ZS
# --------------------------
# country CUW indicator FP.CPI.TOTL
# --------------------------
# country CUW indicator CC.EST
# --------------------------
# country CUW indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country CUW indicator SH.XPD.GHED.PP.CD
# --------------------------
# country TUV indicator NY.GDP.PCAP.KD
# --------------------------
# country TUV indicator SP.POP.TOTL
# --------------------------
# country TUV indicator SL.UEM.ADVN.ZS
# --------------------------
# country TUV indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country TUV indicator SI.POV.DDAY
# --------------------------
# country TUV indicator EN.POP.DNST
# --------------------------
# country TUV indicator ER.H2O.FWST.ZS
# --------------------------
# country TUV indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country TUV indicator SP.RUR.TOTL.ZS
# --------------------------
# country TUV indicator CM.MKT.INDX.ZG
# --------------------------
# country TUV indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country TUV indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country TUV indicator EG.CFT.ACCS.ZS
# --------------------------
# country TUV indicator EG.ELC.ACCS.ZS
# --------------------------
# country TUV indicator per_si_allsi.adq_pop_tot
# --------------------------
# country TUV indicator NY.ADJ.NNTY.KD
# --------------------------
# country TUV indicator AG.LND.ARBL.HA.PC
# --------------------------
# country TUV indicator FB.ATM.TOTL.P5
# --------------------------
# country TUV indicator SE.PRM.UNER.ZS
# --------------------------
# country TUV indicator FP.CPI.TOTL
# --------------------------
# country TUV indicator CC.EST
# --------------------------
# country TUV indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country TUV indicator SH.XPD.GHED.PP.CD
# --------------------------
# country LIE indicator NY.GDP.PCAP.KD
# --------------------------
# country LIE indicator SP.POP.TOTL
# --------------------------
# country LIE indicator SL.UEM.ADVN.ZS
# --------------------------
# country LIE indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country LIE indicator SI.POV.DDAY
# --------------------------
# country LIE indicator EN.POP.DNST
# --------------------------
# country LIE indicator ER.H2O.FWST.ZS
# --------------------------
# country LIE indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country LIE indicator SP.RUR.TOTL.ZS
# --------------------------
# country LIE indicator CM.MKT.INDX.ZG
# --------------------------
# country LIE indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country LIE indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country LIE indicator EG.CFT.ACCS.ZS
# --------------------------
# country LIE indicator EG.ELC.ACCS.ZS
# --------------------------
# country LIE indicator per_si_allsi.adq_pop_tot
# --------------------------
# country LIE indicator NY.ADJ.NNTY.KD
# --------------------------
# country LIE indicator AG.LND.ARBL.HA.PC
# --------------------------
# country LIE indicator FB.ATM.TOTL.P5
# --------------------------
# country LIE indicator SE.PRM.UNER.ZS
# --------------------------
# country LIE indicator FP.CPI.TOTL
# --------------------------
# country LIE indicator CC.EST
# --------------------------
# country LIE indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country LIE indicator SH.XPD.GHED.PP.CD
# --------------------------
# country PRI indicator NY.GDP.PCAP.KD
# --------------------------
# country PRI indicator SP.POP.TOTL
# --------------------------
# country PRI indicator SL.UEM.ADVN.ZS
# --------------------------
# country PRI indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country PRI indicator SI.POV.DDAY
# --------------------------
# country PRI indicator EN.POP.DNST
# --------------------------
# country PRI indicator ER.H2O.FWST.ZS
# --------------------------
# country PRI indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country PRI indicator SP.RUR.TOTL.ZS
# --------------------------
# country PRI indicator CM.MKT.INDX.ZG
# --------------------------
# country PRI indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country PRI indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country PRI indicator EG.CFT.ACCS.ZS
# --------------------------
# country PRI indicator EG.ELC.ACCS.ZS
# --------------------------
# country PRI indicator per_si_allsi.adq_pop_tot
# --------------------------
# country PRI indicator NY.ADJ.NNTY.KD
# --------------------------
# country PRI indicator AG.LND.ARBL.HA.PC
# --------------------------
# country PRI indicator FB.ATM.TOTL.P5
# --------------------------
# country PRI indicator SE.PRM.UNER.ZS
# --------------------------
# country PRI indicator FP.CPI.TOTL
# --------------------------
# country PRI indicator CC.EST
# --------------------------
# country PRI indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country PRI indicator SH.XPD.GHED.PP.CD
# --------------------------
# country PYF indicator NY.GDP.PCAP.KD
# --------------------------
# country PYF indicator SP.POP.TOTL
# --------------------------
# country PYF indicator SL.UEM.ADVN.ZS
# --------------------------
# country PYF indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country PYF indicator SI.POV.DDAY
# --------------------------
# country PYF indicator EN.POP.DNST
# --------------------------
# country PYF indicator ER.H2O.FWST.ZS
# --------------------------
# country PYF indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country PYF indicator SP.RUR.TOTL.ZS
# --------------------------
# country PYF indicator CM.MKT.INDX.ZG
# --------------------------
# country PYF indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country PYF indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country PYF indicator EG.CFT.ACCS.ZS
# --------------------------
# country PYF indicator EG.ELC.ACCS.ZS
# --------------------------
# country PYF indicator per_si_allsi.adq_pop_tot
# --------------------------
# country PYF indicator NY.ADJ.NNTY.KD
# --------------------------
# country PYF indicator AG.LND.ARBL.HA.PC
# --------------------------
# country PYF indicator FB.ATM.TOTL.P5
# --------------------------
# country PYF indicator SE.PRM.UNER.ZS
# --------------------------
# country PYF indicator FP.CPI.TOTL
# --------------------------
# country PYF indicator CC.EST
# --------------------------
# country PYF indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country PYF indicator SH.XPD.GHED.PP.CD
# --------------------------
# country NRU indicator NY.GDP.PCAP.KD
# --------------------------
# country NRU indicator SP.POP.TOTL
# --------------------------
# country NRU indicator SL.UEM.ADVN.ZS
# --------------------------
# country NRU indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country NRU indicator SI.POV.DDAY
# --------------------------
# country NRU indicator EN.POP.DNST
# --------------------------
# country NRU indicator ER.H2O.FWST.ZS
# --------------------------
# country NRU indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country NRU indicator SP.RUR.TOTL.ZS
# --------------------------
# country NRU indicator CM.MKT.INDX.ZG
# --------------------------
# country NRU indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country NRU indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country NRU indicator EG.CFT.ACCS.ZS
# --------------------------
# country NRU indicator EG.ELC.ACCS.ZS
# --------------------------
# country NRU indicator per_si_allsi.adq_pop_tot
# --------------------------
# country NRU indicator NY.ADJ.NNTY.KD
# --------------------------
# country NRU indicator AG.LND.ARBL.HA.PC
# --------------------------
# country NRU indicator FB.ATM.TOTL.P5
# --------------------------
# country NRU indicator SE.PRM.UNER.ZS
# --------------------------
# country NRU indicator FP.CPI.TOTL
# --------------------------
# country NRU indicator CC.EST
# --------------------------
# country NRU indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country NRU indicator SH.XPD.GHED.PP.CD
# --------------------------
# country STP indicator NY.GDP.PCAP.KD
# --------------------------
# country STP indicator SP.POP.TOTL
# --------------------------
# country STP indicator SL.UEM.ADVN.ZS
# --------------------------
# country STP indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country STP indicator SI.POV.DDAY
# --------------------------
# country STP indicator EN.POP.DNST
# --------------------------
# country STP indicator ER.H2O.FWST.ZS
# --------------------------
# country STP indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country STP indicator SP.RUR.TOTL.ZS
# --------------------------
# country STP indicator CM.MKT.INDX.ZG
# --------------------------
# country STP indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country STP indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country STP indicator EG.CFT.ACCS.ZS
# --------------------------
# country STP indicator EG.ELC.ACCS.ZS
# --------------------------
# country STP indicator per_si_allsi.adq_pop_tot
# --------------------------
# country STP indicator NY.ADJ.NNTY.KD
# --------------------------
# country STP indicator AG.LND.ARBL.HA.PC
# --------------------------
# country STP indicator FB.ATM.TOTL.P5
# --------------------------
# country STP indicator SE.PRM.UNER.ZS
# --------------------------
# country STP indicator FP.CPI.TOTL
# --------------------------
# country STP indicator CC.EST
# --------------------------
# country STP indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country STP indicator SH.XPD.GHED.PP.CD
# --------------------------
# country VUT indicator NY.GDP.PCAP.KD
# --------------------------
# country VUT indicator SP.POP.TOTL
# --------------------------
# country VUT indicator SL.UEM.ADVN.ZS
# --------------------------
# country VUT indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country VUT indicator SI.POV.DDAY
# --------------------------
# country VUT indicator EN.POP.DNST
# --------------------------
# country VUT indicator ER.H2O.FWST.ZS
# --------------------------
# country VUT indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country VUT indicator SP.RUR.TOTL.ZS
# --------------------------
# country VUT indicator CM.MKT.INDX.ZG
# --------------------------
# country VUT indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country VUT indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country VUT indicator EG.CFT.ACCS.ZS
# --------------------------
# country VUT indicator EG.ELC.ACCS.ZS
# --------------------------
# country VUT indicator per_si_allsi.adq_pop_tot
# --------------------------
# country VUT indicator NY.ADJ.NNTY.KD
# --------------------------
# country VUT indicator AG.LND.ARBL.HA.PC
# --------------------------
# country VUT indicator FB.ATM.TOTL.P5
# --------------------------
# country VUT indicator SE.PRM.UNER.ZS
# --------------------------
# country VUT indicator FP.CPI.TOTL
# --------------------------
# country VUT indicator CC.EST
# --------------------------
# country VUT indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country VUT indicator SH.XPD.GHED.PP.CD
# --------------------------
# country SXM indicator NY.GDP.PCAP.KD
# --------------------------
# country SXM indicator SP.POP.TOTL
# --------------------------
# country SXM indicator SL.UEM.ADVN.ZS
# --------------------------
# country SXM indicator SL.UEM.TOTL.NE.ZS
# --------------------------
# country SXM indicator SI.POV.DDAY
# --------------------------
# country SXM indicator EN.POP.DNST
# --------------------------
# country SXM indicator ER.H2O.FWST.ZS
# --------------------------
# country SXM indicator CM.MKT.LCAP.GD.ZS
# --------------------------
# country SXM indicator SP.RUR.TOTL.ZS
# --------------------------
# country SXM indicator CM.MKT.INDX.ZG
# --------------------------
# country SXM indicator VA.NO.SRCEG.ELC.ACCS.ZS
# country SXM indicator VA.NO.SRCEG.ELC.ACCS.ZS....... not found
# --------------------------
# country SXM indicator EG.CFT.ACCS.ZS
# --------------------------
# country SXM indicator EG.ELC.ACCS.ZS
# --------------------------
# country SXM indicator per_si_allsi.adq_pop_tot
# --------------------------
# country SXM indicator NY.ADJ.NNTY.KD
# --------------------------
# country SXM indicator AG.LND.ARBL.HA.PC
# --------------------------
# country SXM indicator FB.ATM.TOTL.P5
# --------------------------
# country SXM indicator SE.PRM.UNER.ZS
# --------------------------
# country SXM indicator FP.CPI.TOTL
# --------------------------
# country SXM indicator CC.EST
# --------------------------
# country SXM indicator SH.XPD.CHEX.PP.CD
# --------------------------
# country SXM indicator SH.XPD.GHED.PP.CD

# %%
## Create DF with the previous output

macro_eco_data_df = pd.DataFrame(macro_eco_data_list)
macro_eco_data_df = macro_eco_data_df.dropna(how='all')

macro_eco_data_df.head()
# Out:
#   iso3Code iso2Code      country  year                           indicator  \
# 0      AFG       AF  Afghanistan  2023  GDP per capita (constant 2015 US$)
# 1      AFG       AF  Afghanistan  2022  GDP per capita (constant 2015 US$)
# 2      AFG       AF  Afghanistan  2021  GDP per capita (constant 2015 US$)
# 3      AFG       AF  Afghanistan  2020  GDP per capita (constant 2015 US$)
# 4      AFG       AF  Afghanistan  2019  GDP per capita (constant 2015 US$)
#
#         value
# 0  379.707497
# 1  377.665627
# 2  408.625855
# 3  527.834554
# 4  557.861533

# %%
print(f'size of the DF : {macro_eco_data_df.shape}')
print('................')
print(macro_eco_data_df.dtypes)
# Out:
# size of the DF : (38367, 6)
# ................
# iso3Code      object
# iso2Code      object
# country       object
# year          object
# indicator     object
# value        float64
# dtype: object

# %%
# change datatype 

macro_eco_data_df = macro_eco_data_df.astype({'year':'int64'})
macro_eco_data_df.dtypes
# Out:
# iso3Code      object
# iso2Code      object
# country       object
# year           int64
# indicator     object
# value        float64
# dtype: object

# %%
# export to csv

macro_eco_data_df.to_csv('Output/macro_economic_data.csv')
